# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.tools as tools
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

tools.set_credentials_file(username='saeedesmaili', api_key='TU3U83YV7K3u348OMgdu')
init_notebook_mode(connected=True)

plt.style.use('ggplot')
pd.set_option('display.max_columns', 500)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.read_csv('data_1394_1397.csv', converters={
    'programming_languages': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'wanting_to_work_languages': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'database': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'desktop_os': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'server_os': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'mobile_os': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'ide': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'drinks': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'position': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'company_type': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'company_benefits': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'style_': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'change_in_body': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'music_style': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'source_control': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(","),
    'technology': lambda x: x.replace("[", "").replace("'", "").replace(']','').split(",")
}, encoding = 'utf-8')

df_ = pd.read_csv('data_1394_1397.csv')

df.head()
# Out:
#              timestamp       age gender   home_province work_province  \
# 0  2016-02-21 16:41:37  ۲۳ تا ۲۹    مرد           تهران         تهران
# 1  2016-02-21 16:45:37  ۲۳ تا ۲۹    مرد           تهران         تهران
# 2  2016-02-21 16:47:21  ۲۳ تا ۲۹    مرد           تهران         تهران
# 3  2016-02-21 16:49:20  ۲۳ تا ۲۹    مرد  آذربایجان غربی         تهران
# 4  2016-02-21 16:52:44  ۳۰ تا ۳۹     زن         خوزستان         تهران
#
#     experience_years                   education international_certificates  \
# 0  هفت تا پانزده سال                      لیسانس                    هیچکدام
# 1  هفت تا پانزده سال                      لیسانس                    هیچکدام
# 2       یک تا سه سال  در حال تحصیل در فوق لیسانس                    هیچکدام
# 3       یک تا سه سال                  فوق لیسانس                    هیچکدام
# 4  هفت تا پانزده سال                      لیسانس                    هیچکدام
#
#     learning_per_week fun_projects_per_week books_read_last_three_months  \
# 0      دو تا هفت ساعت       کمتر از دو ساعت                     دو یا سه
# 1      دو تا هفت ساعت        دو تا هفت ساعت                     دو یا سه
# 2     کمتر از دو ساعت       کمتر از دو ساعت                     دو یا سه
# 3  هفت تا چهارده ساعت       کمتر از دو ساعت                     دو یا سه
# 4     کمتر از دو ساعت       کمتر از دو ساعت                     دو یا سه
#
#                                programming_languages  \
# 0  [سی شارپ,   پایتون,   ویژوال بیسیک,   جاوااسکر...
# 1  [سی شارپ,   جاوااسکریپت,   اسکوئل,   ای اس پی ...
# 2                  [جاوا,   پی اچ پی,   جاوااسکریپت]
# 3  [سی پلاس پلاس,   سی شارپ,   پایتون,   جاوااسکر...
# 4                           [سی شارپ,   جاوااسکریپت]
#
#   wanting_to_work_languages  \
# 0                 [هیچکدام]
# 1                 [هیچکدام]
# 2                 [هیچکدام]
# 3                 [هیچکدام]
# 4                 [هیچکدام]
#
#                                             database  \
# 0                      [MS-SQL,   sqlite,   MongoDB]
# 1                                  [MS-SQL,   Redis]
# 2                         [MySQL/MariaDB,   MongoDB]
# 3  [MS-SQL,   sqlite,   Hadoop Based technoloties...
# 4                                           [MS-SQL]
#
#                    desktop_os  \
# 0           [ویندوز ده,   مک]
# 1  [ویندوز هفت,   ویندوز هشت]
# 2                        [مک]
# 3                 [ویندوز ده]
# 4                [ویندوز هشت]
#
#                                            server_os   mobile_os  \
# 0  [ویندوز سرور ۲۰۱۶,   لینوکس دبیان,   لینوکس او...  [آی او اس]
# 1  [ویندوز سرور ۲۰۰۳,   ویندوز سرور ۲۰۰۸,   ویندو...   [اندروید]
# 2                                 [لینوکس سنت او اس]  [آی او اس]
# 3  [ویندوز سرور ۲۰۱۲,   ویندوز سرور ۲۰۱۶,   لینوک...   [اندروید]
# 4                                   [ویندوزهای دیگر]  [آی او اس]
#
#                                                  ide            ide_theme  \
# 0             [ویژوال استودیو,   سابلایم,   ایکس کد]                 روشن
# 1  [ویژوال استودیو,   ادیتورهای متن ساده (نوت پد ...  گاهی روشن گاهی تیره
# 2  [سابلایم,   محصولات جت برین,   ویم,   محصولات ...                 تیره
# 3  [ویژوال استودیو,   سابلایم,   براکت,   محصولات...  گاهی روشن گاهی تیره
# 4                                   [ویژوال استودیو]                 تیره
#
#   source_control  tab_or_space                         drinks about_you  \
# 0          [گیت]            تب                         [قهوه]   هیچکدام
# 1          [گیت]            تب                           [آب]   هیچکدام
# 2          [گیت]  تفاوتی ندارد            [چای,   قهوه,   آب]   هیچکدام
# 3      [هیچکدام]            تب                          [چای]   هیچکدام
# 4          [گیت]            تب  [چای,   دمنوش\u200cهای متنوع]   هیچکدام
#
#   how_many_devices                                 position  \
# 0          هیچکدام                [توسعه دهنده فول استک وب]
# 1          هیچکدام                     [توسعه دهنده بک اند]
# 2          هیچکدام                     [توسعه دهنده بک اند]
# 3          هیچکدام                           [دانشمند داده]
# 4          هیچکدام  [توسعه دهنده بک اند,   طراح,   تحلیلگر]
#
#                              company_type  employees      avg_monthly_salary  \
# 0              [شرکت های تولید نرم افزار]       20.0       پنج تا هفت میلیون
# 1              [شرکت های تولید نرم افزار]       25.0  سه و نیم تا پنج میلیون
# 2              [شرکت های تولید نرم افزار]       30.0   دو تا سه و نیم میلیون
# 3  [شرکت های ارائه دهنده سرویس های مختلف]       25.0   دو تا سه و نیم میلیون
# 4              [شرکت های تولید نرم افزار]       25.0       پنج تا هفت میلیون
#
#   company_benefits       work_type                                   work_way  \
# 0        [هیچکدام]  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 1        [هیچکدام]  تمام وقت خصوصی  اکثر وقت‌ها در دفتر ولی دورکاری هم می کنم
# 2        [هیچکدام]  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 3        [هیچکدام]  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 4        [هیچکدام]  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
#
#              wage_per_hour  satisfaction     style_ change_in_body  \
# 0        ساعتی کار نمی کنم             4  [هیچکدام]      [هیچکدام]
# 1  بین بیست و پنج تا پنجاه             5  [هیچکدام]      [هیچکدام]
# 2        ساعتی کار نمی کنم             5  [هیچکدام]      [هیچکدام]
# 3        ساعتی کار نمی کنم             5  [هیچکدام]      [هیچکدام]
# 4                  هیچکدام             4  [هیچکدام]      [هیچکدام]
#
#   music_style relationship technology  survey_year learning_where  \
# 0   [هیچکدام]      هیچکدام  [هیچکدام]         1394        هیچکدام
# 1   [هیچکدام]      هیچکدام  [هیچکدام]         1394        هیچکدام
# 2   [هیچکدام]      هیچکدام  [هیچکدام]         1394        هیچکدام
# 3   [هیچکدام]      هیچکدام  [هیچکدام]         1394        هیچکدام
# 4   [هیچکدام]      هیچکدام  [هیچکدام]         1394        هیچکدام
#
#   useful_services is_main_job
# 0         هیچکدام     هیچکدام
# 1         هیچکدام     هیچکدام
# 2         هیچکدام     هیچکدام
# 3         هیچکدام     هیچکدام
# 4         هیچکدام     هیچکدام

# %%
df_[df_.duplicated()]
# Out:
# Empty DataFrame
# Columns: [timestamp, age, gender, home_province, work_province, experience_years, education, international_certificates, learning_per_week, fun_projects_per_week, books_read_last_three_months, programming_languages, wanting_to_work_languages, database, desktop_os, server_os, mobile_os, ide, ide_theme, source_control, tab_or_space, drinks, about_you, how_many_devices, position, company_type, employees, avg_monthly_salary, company_benefits, work_type, work_way, wage_per_hour, satisfaction, style_, change_in_body, music_style, relationship, technology, survey_year, learning_where, useful_services, is_main_job]
# Index: []
