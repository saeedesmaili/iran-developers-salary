# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')
pd.set_option('display.max_columns', 500)

# %%
df_94 = pd.read_csv('data/1394.csv')
df_94.head()
# Out:
#             Timestamp در کدام محدوده سنی هستید؟ جنسیت  \
# 0  2/21/2016 16:41:37                  ۲۳ تا ۲۹   مرد
# 1  2/21/2016 16:45:37                  ۲۳ تا ۲۹   مرد
# 2  2/21/2016 16:47:21                  ۲۳ تا ۲۹   مرد
# 3  2/21/2016 16:49:20                  ۲۳ تا ۲۹   مرد
# 4  2/21/2016 16:52:44                  ۳۰ تا ۳۹    زن
#
#   خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (: استان محل کار  \
# 0                                              تهران             تهران
# 1                                              تهران             تهران
# 2                                              تهران             تهران
# 3                                     آذربایجان غربی             تهران
# 4                                            خوزستان             تهران
#
#   چند سال تجربه کار تمام وقت دارید؟          آخرین وضعیت تحصیلی  \
# 0                 هفت تا پانزده سال                      لیسانس
# 1                 هفت تا پانزده سال                      لیسانس
# 2                      یک تا سه سال  در حال تحصیل در فوق لیسانس
# 3                      یک تا سه سال                  فوق لیسانس
# 4                 هفت تا پانزده سال                      لیسانس
#
#   چه مدارک بین المللی ای اخذ کرده اید  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟  \
# 0                                     دو تا هفت ساعت
# 1                                     دو تا هفت ساعت
# 2                                    کمتر از دو ساعت
# 3                                 هفت تا چهارده ساعت
# 4                                    کمتر از دو ساعت
#
#   چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟  \
# 0                                    کمتر از دو ساعت
# 1                                     دو تا هفت ساعت
# 2                                    کمتر از دو ساعت
# 3                                    کمتر از دو ساعت
# 4                                    کمتر از دو ساعت
#
#   در سه ماه گذشته چند کتاب خوانده اید؟  \
# 0                             دو یا سه
# 1                             دو یا سه
# 2                             دو یا سه
# 3                             دو یا سه
# 4                             دو یا سه
#
#   زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟  \
# 0  سی شارپ, پایتون, ویژوال بیسیک, جاوااسکریپت, سو...
# 1      سی شارپ, جاوااسکریپت, اسکوئل, ای اس پی دات نت
# 2                        جاوا, پی اچ پی, جاوااسکریپت
# 3  سی پلاس پلاس, سی شارپ, پایتون, جاوااسکریپت, اس...
# 4                               سی شارپ, جاوااسکریپت
#
#   به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             دیتابیس‌های مورد استفاده  \
# 0                            MS-SQL, sqlite, MongoDB
# 1                                      MS-SQL, Redis
# 2                             MySQL/MariaDB, MongoDB
# 3  MS-SQL, sqlite, Hadoop Based technoloties, Mon...
# 4                                             MS-SQL
#
#   سیستم عامل رومیزی شما کدام است؟  \
# 0                   ویندوز ده, مک
# 1          ویندوز هفت, ویندوز هشت
# 2                              مک
# 3                       ویندوز ده
# 4                      ویندوز هشت
#
#                       سیستم عامل سرور مورد علاقه شما  \
# 0     ویندوز سرور ۲۰۱۶, لینوکس دبیان, لینوکس اوبونتو
# 1  ویندوز سرور ۲۰۰۳, ویندوز سرور ۲۰۰۸, ویندوز سرو...
# 2                                   لینوکس سنت او اس
# 3  ویندوز سرور ۲۰۱۲, ویندوز سرور ۲۰۱۶, لینوکس اوب...
# 4                                     ویندوزهای دیگر
#
#   و وقتی صحبت از تلفن همراه باشد...  \
# 0                          آی او اس
# 1                           اندروید
# 2                          آی او اس
# 3                           اندروید
# 4                          آی او اس
#
#                     در چه محیطی برنامه نویسی می‌کنید          تم آی دی ای  \
# 0                   ویژوال استودیو, سابلایم, ایکس کد                 روشن
# 1  ویژوال استودیو, ادیتورهای متن ساده (نوت پد پلا...  گاهی روشن گاهی تیره
# 2      سابلایم, محصولات جت برین, ویم, محصولات اکلیپس                 تیره
# 3     ویژوال استودیو, سابلایم, براکت, محصولات اکلیپس  گاهی روشن گاهی تیره
# 4                                     ویژوال استودیو                 تیره
#
#   از چه سورس کنترلی استفاده می کنید؟  تب یا اسپیس؟ نوشیدنی‌های اصلی شما چیست؟  \
# 0                                گیت            تب                       قهوه
# 1                                گیت            تب                         آب
# 2                                گیت  تفاوتی ندارد              چای, قهوه, آب
# 3                                NaN            تب                        چای
# 4                                گیت            تب       چای, دمنوش‌های متنوع
#
#   کدام‌ها در مورد شما صدق می‌کند  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#    به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   حوزه کاری شما چیست                نوع شرکت شما کدام است؟  \
# 0            توسعه دهنده فول استک وب              شرکت های تولید نرم افزار
# 1                 توسعه دهنده بک اند              شرکت های تولید نرم افزار
# 2                 توسعه دهنده بک اند              شرکت های تولید نرم افزار
# 3                       دانشمند داده  شرکت های ارائه دهنده سرویس های مختلف
# 4  توسعه دهنده بک اند, طراح, تحلیلگر              شرکت های تولید نرم افزار
#
#    تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)  \
# 0                                                 20
# 1                                                 25
# 2                                                 30
# 3                                                 25
# 4                                                 25
#
#   متوسط درآمد ماهیانه شما (به تومان)  \
# 0                  پنج تا هفت میلیون
# 1             سه و نیم تا پنج میلیون
# 2              دو تا سه و نیم میلیون
# 3              دو تا سه و نیم میلیون
# 4                  پنج تا هفت میلیون
#
#   محل کار چه خدماتی بیشتر از حقوق ارائه می دهد چگونه کار می کنید؟  \
# 0                                          NaN     تمام وقت خصوصی
# 1                                          NaN     تمام وقت خصوصی
# 2                                          NaN     تمام وقت خصوصی
# 3                                          NaN     تمام وقت خصوصی
# 4                                          NaN     تمام وقت خصوصی
#
#                       شیوه کار شما کدام است؟  \
# 0          تمام وقت‌های کاری را در دفتر هستم
# 1  اکثر وقت‌ها در دفتر ولی دورکاری هم می کنم
# 2          تمام وقت‌های کاری را در دفتر هستم
# 3          تمام وقت‌های کاری را در دفتر هستم
# 4          تمام وقت‌های کاری را در دفتر هستم
#
#   در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)  \
# 0                                  ساعتی کار نمی کنم
# 1                            بین بیست و پنج تا پنجاه
# 2                                  ساعتی کار نمی کنم
# 3                                  ساعتی کار نمی کنم
# 4                                                NaN
#
#    چقدر از کاری که انتخاب کرده اید راضی هستید؟  \
# 0                                            4
# 1                                            5
# 2                                            5
# 3                                            5
# 4                                            4
#
#   آیا نکته ای هست که بخواهید اضافه کنید؟ بنویسید...  تیپ   تغییر در بدن؟  \
# 0                                               NaN   NaN            NaN
# 1                                               NaN   NaN            NaN
# 2                                               NaN   NaN            NaN
# 3                                               NaN   NaN            NaN
# 4                                               NaN   NaN            NaN
#
#    سبک موسیقی  وضعیت رابطه  از کدام تکنولوزی ها استفاده می کنید  سبک لباس
# 0         NaN          NaN                                  NaN       NaN
# 1         NaN          NaN                                  NaN       NaN
# 2         NaN          NaN                                  NaN       NaN
# 3         NaN          NaN                                  NaN       NaN
# 4         NaN          NaN                                  NaN       NaN

# %%
df_94.columns
# Out:
# Index(['Timestamp', 'در کدام محدوده سنی هستید؟', 'جنسیت',
#        'خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (:',
#        'استان محل کار', 'چند سال تجربه کار تمام وقت دارید؟',
#        'آخرین وضعیت تحصیلی', 'چه مدارک بین المللی ای اخذ کرده اید',
#        'چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟',
#        'چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟',
#        'در سه ماه گذشته چند کتاب خوانده اید؟',
#        'زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟',
#        'به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟',
#        'دیتابیس‌های مورد استفاده', 'سیستم عامل رومیزی شما کدام است؟',
#        'سیستم عامل سرور مورد علاقه شما', 'و وقتی صحبت از تلفن همراه باشد...',
#        'در چه محیطی برنامه نویسی می‌کنید', 'تم آی دی ای',
#        'از چه سورس کنترلی استفاده می کنید؟', 'تب یا اسپیس؟',
#        'نوشیدنی‌های اصلی شما چیست؟', 'کدام‌ها در مورد شما صدق می‌کند',
#        'به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)',
#        'حوزه کاری شما چیست', 'نوع شرکت شما کدام است؟',
#        'تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)',
#        'متوسط درآمد ماهیانه شما (به تومان)',
#        'محل کار چه خدماتی بیشتر از حقوق ارائه می دهد', 'چگونه کار می کنید؟',
#        'شیوه کار شما کدام است؟',
#        'در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)',
#        'چقدر از کاری که انتخاب کرده اید راضی هستید؟',
#        'آیا نکته ای هست که بخواهید اضافه کنید؟ بنویسید...', 'تیپ ',
#        'تغییر در بدن؟', 'سبک موسیقی', 'وضعیت رابطه',
#        'از کدام تکنولوزی ها استفاده می کنید', 'سبک لباس'],
#       dtype='object')

# %%
df_94.columns = ('time', 'age', 'gender', 'home_province', 'work_province', 'experience_years', 'education', 'international_certificates', 'learning_per_week', 'fun_projects_per_week', 'books_read_last_three_months', 'programming_languages', 'want_to_work_languages', 'database', 'desktop_os', 'server_os', 'mobile_os', 'ide', 'ide_theme', 'source_control', 'tab_or_space', 'drinks', 'about_you', 'how_many_devices', 'position', 'company_type', 'employees', 'avg_monthly_salary', 'company_benefits', 'work_type', 'work_way', 'wage_per_hour', 'satisfaction', 'comment', 'style_', 'change_in_body', 'music_style', 'relationship', 'technology', 'clothing_style')

# %%
df_94.head()
# Out:
#                  time       age gender   home_province work_province  \
# 0  2/21/2016 16:41:37  ۲۳ تا ۲۹    مرد           تهران         تهران
# 1  2/21/2016 16:45:37  ۲۳ تا ۲۹    مرد           تهران         تهران
# 2  2/21/2016 16:47:21  ۲۳ تا ۲۹    مرد           تهران         تهران
# 3  2/21/2016 16:49:20  ۲۳ تا ۲۹    مرد  آذربایجان غربی         تهران
# 4  2/21/2016 16:52:44  ۳۰ تا ۳۹     زن         خوزستان         تهران
#
#     experience_years                   education international_certificates  \
# 0  هفت تا پانزده سال                      لیسانس                        NaN
# 1  هفت تا پانزده سال                      لیسانس                        NaN
# 2       یک تا سه سال  در حال تحصیل در فوق لیسانس                        NaN
# 3       یک تا سه سال                  فوق لیسانس                        NaN
# 4  هفت تا پانزده سال                      لیسانس                        NaN
#
#     learning_per_week fun_projects_per_week books_read_last_three_months  \
# 0      دو تا هفت ساعت       کمتر از دو ساعت                     دو یا سه
# 1      دو تا هفت ساعت        دو تا هفت ساعت                     دو یا سه
# 2     کمتر از دو ساعت       کمتر از دو ساعت                     دو یا سه
# 3  هفت تا چهارده ساعت       کمتر از دو ساعت                     دو یا سه
# 4     کمتر از دو ساعت       کمتر از دو ساعت                     دو یا سه
#
#                                programming_languages want_to_work_languages  \
# 0  سی شارپ, پایتون, ویژوال بیسیک, جاوااسکریپت, سو...                    NaN
# 1      سی شارپ, جاوااسکریپت, اسکوئل, ای اس پی دات نت                    NaN
# 2                        جاوا, پی اچ پی, جاوااسکریپت                    NaN
# 3  سی پلاس پلاس, سی شارپ, پایتون, جاوااسکریپت, اس...                    NaN
# 4                               سی شارپ, جاوااسکریپت                    NaN
#
#                                             database              desktop_os  \
# 0                            MS-SQL, sqlite, MongoDB           ویندوز ده, مک
# 1                                      MS-SQL, Redis  ویندوز هفت, ویندوز هشت
# 2                             MySQL/MariaDB, MongoDB                      مک
# 3  MS-SQL, sqlite, Hadoop Based technoloties, Mon...               ویندوز ده
# 4                                             MS-SQL              ویندوز هشت
#
#                                            server_os mobile_os  \
# 0     ویندوز سرور ۲۰۱۶, لینوکس دبیان, لینوکس اوبونتو  آی او اس
# 1  ویندوز سرور ۲۰۰۳, ویندوز سرور ۲۰۰۸, ویندوز سرو...   اندروید
# 2                                   لینوکس سنت او اس  آی او اس
# 3  ویندوز سرور ۲۰۱۲, ویندوز سرور ۲۰۱۶, لینوکس اوب...   اندروید
# 4                                     ویندوزهای دیگر  آی او اس
#
#                                                  ide            ide_theme  \
# 0                   ویژوال استودیو, سابلایم, ایکس کد                 روشن
# 1  ویژوال استودیو, ادیتورهای متن ساده (نوت پد پلا...  گاهی روشن گاهی تیره
# 2      سابلایم, محصولات جت برین, ویم, محصولات اکلیپس                 تیره
# 3     ویژوال استودیو, سابلایم, براکت, محصولات اکلیپس  گاهی روشن گاهی تیره
# 4                                     ویژوال استودیو                 تیره
#
#   source_control  tab_or_space                drinks about_you  \
# 0            گیت            تب                  قهوه       NaN
# 1            گیت            تب                    آب       NaN
# 2            گیت  تفاوتی ندارد         چای, قهوه, آب       NaN
# 3            NaN            تب                   چای       NaN
# 4            گیت            تب  چای, دمنوش‌های متنوع       NaN
#
#    how_many_devices                           position  \
# 0               NaN            توسعه دهنده فول استک وب
# 1               NaN                 توسعه دهنده بک اند
# 2               NaN                 توسعه دهنده بک اند
# 3               NaN                       دانشمند داده
# 4               NaN  توسعه دهنده بک اند, طراح, تحلیلگر
#
#                            company_type  employees      avg_monthly_salary  \
# 0              شرکت های تولید نرم افزار         20       پنج تا هفت میلیون
# 1              شرکت های تولید نرم افزار         25  سه و نیم تا پنج میلیون
# 2              شرکت های تولید نرم افزار         30   دو تا سه و نیم میلیون
# 3  شرکت های ارائه دهنده سرویس های مختلف         25   دو تا سه و نیم میلیون
# 4              شرکت های تولید نرم افزار         25       پنج تا هفت میلیون
#
#   company_benefits       work_type                                   work_way  \
# 0              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 1              NaN  تمام وقت خصوصی  اکثر وقت‌ها در دفتر ولی دورکاری هم می کنم
# 2              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 3              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 4              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
#
#              wage_per_hour  satisfaction comment  style_  change_in_body  \
# 0        ساعتی کار نمی کنم             4     NaN     NaN             NaN
# 1  بین بیست و پنج تا پنجاه             5     NaN     NaN             NaN
# 2        ساعتی کار نمی کنم             5     NaN     NaN             NaN
# 3        ساعتی کار نمی کنم             5     NaN     NaN             NaN
# 4                      NaN             4     NaN     NaN             NaN
#
#    music_style  relationship  technology  clothing_style
# 0          NaN           NaN         NaN             NaN
# 1          NaN           NaN         NaN             NaN
# 2          NaN           NaN         NaN             NaN
# 3          NaN           NaN         NaN             NaN
# 4          NaN           NaN         NaN             NaN

# %%
df_95 = pd.read_csv('data/1395.csv')
df_95.head()
# Out:
#             Timestamp در کدام محدوده سنی هستید؟ جنسیت  \
# 0  2/28/2017 17:44:04                  ۲۳ تا ۲۹   مرد
# 1  2/28/2017 17:41:58                  ۲۳ تا ۲۹   مرد
# 2  2/28/2017 17:45:04                  ۲۳ تا ۲۹   مرد
# 3  2/28/2017 17:53:54                  ۲۳ تا ۲۹   مرد
# 4  2/28/2017 17:57:19                  ۲۳ تا ۲۹   مرد
#
#   خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (: استان محل کار  \
# 0                                              تهران             تهران
# 1                                              تهران             تهران
# 2                                               فارس             تهران
# 3                                              البرز             البرز
# 4                                              البرز             تهران
#
#   چند سال تجربه کار تمام وقت دارید؟          آخرین وضعیت تحصیلی  \
# 0                 هفت تا پانزده سال                      لیسانس
# 1                     سه تا هفت سال  در حال تحصیل در فوق لیسانس
# 2                     سه تا هفت سال                      لیسانس
# 3                     سه تا هفت سال  در حال تحصیل در فوق لیسانس
# 4                      یک تا سه سال  در حال تحصیل در فوق لیسانس
#
#   چه مدارک بین المللی ای اخذ کرده اید  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟  \
# 0                                     دو تا هفت ساعت
# 1                                     دو تا هفت ساعت
# 2                                     دو تا هفت ساعت
# 3                                 هفت تا چهارده ساعت
# 4                                     دو تا هفت ساعت
#
#   چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟  \
# 0                                     دو تا هفت ساعت
# 1                                     دو تا هفت ساعت
# 2                                                صفر
# 3                                     دو تا هفت ساعت
# 4                                                صفر
#
#   در سه ماه گذشته چند کتاب خوانده اید؟  \
# 0                                  هیچ
# 1                             دو یا سه
# 2                             سه تا شش
# 3                                  هیچ
# 4                                   یک
#
#   زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟  \
# 0                               PHP, Javascript, SQL
# 1                         Java, PHP, Javascript, SQL
# 2                          C#, Javascript, SQL, Bash
# 3                              Java, PHP, Javascript
# 4                               PHP, Javascript, SQL
#
#   به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟  \
# 0                            Python, Ruby, Swift, Go
# 1                                              Swift
# 2                                 Python, PHP, Swift
# 3                                         C#, Python
# 4          Java, Python, PHP, Javascript, Swift, SQL
#
#                     دیتابیس‌های مورد استفاده  \
# 0  MySQL/MariaDB, Postgresql, MongoDB, Redis
# 1   MySQL/MariaDB, Postgresql, sqlite, Redis
# 2              MS-SQL, MySQL/MariaDB, Oracle
# 3                      MySQL/MariaDB, sqlite
# 4        No Database, MySQL/MariaDB, MongoDB
#
#        سیستم عامل رومیزی شما کدام است؟     سیستم عامل سرور مورد علاقه شما  \
# 0                                 OS X         Linux Debian, Linux Ubuntu
# 1                                 OS X                       Linux CentOS
# 2  Windows 7, Windows 10, Linux Ubuntu  Windows Server 2012, Linux Debian
# 3                           Windows 10                       Linux CentOS
# 4       Windows 10, OS X, Linux Ubuntu                 Linux Ubuntu, os x
#
#   و وقتی صحبت از تلفن همراه باشد... در چه محیطی برنامه نویسی می‌کنید  \
# 0                               iOS                     سابلایم, ویم
# 1                      Android, iOS         سابلایم, محصولات جت برین
# 2                           Android                   ویژوال استودیو
# 3                      Android, iOS                  محصولات جت برین
# 4                           Android                   محصولات اکلیپس
#
#   تم آی دی ای از چه سورس کنترلی استفاده می کنید؟  \
# 0        تیره                                گیت
# 1        تیره                                گیت
# 2        تیره                                گیت
# 3        تیره                                گیت
# 4        تیره                                گیت
#
#             از کدام تکنولوزی ها استفاده می کنید  تب یا اسپیس؟  \
# 0  سورس کنترل, کانتینرها, تست های خودکار, کلاود            تب
# 1                                    سورس کنترل            تب
# 2                                    سورس کنترل         اسپیس
# 3                                    سورس کنترل            تب
# 4                        سورس کنترل, هوش مصنوعی  تفاوتی ندارد
#
#                           نوشیدنی‌های اصلی شما چیست؟  \
# 0  چای, قهوه, انرژی زا, نوشابه, انواع ماء الشعیر,...
# 1                                            چای, آب
# 2                        چای, قهوه, انرژی زا, نوشابه
# 3                                            چای, آب
# 4                                          چای, قهوه
#
#                                                 تیپ  تغییر در بدن؟  \
# 0  تی شرت, جین, پیرهن مردونه, گجت پوشیدنی دارم (س...           NaN
# 1                                       تیره, اسپورت           NaN
# 2               تی شرت, جین, رنگی رنگی, روشن, اسپورت           NaN
# 3  تی شرت, جین, پیرهن مردونه, ساعت می بندم, اسپور...           NaN
# 4                          تی شرت, جین, پیرهن مردونه           NaN
#
#                       کدام‌ها در مورد شما صدق می‌کند  \
# 0  بیشتر از سه بار در هفته ورزش می کنم, سیاست برا...
# 1  بیشتر از یک نخ در روز سیگار می کشم, سیاست برای...
# 2                 در رابطه نیستم ولی دوست داشتم بودم
# 3                                                NaN
# 4  بیشتر از یک نخ در روز سیگار می کشم, حداقل یک ر...
#
#                           سبک موسیقی  \
# 0                      الکترونیک دنس
# 1                 پاپ ایرانی, دامبول
# 2  پاپ ایرانی, پاپ خارجی, رپ, دامبول
# 3                                NaN
# 4               پاپ خارجی, متال, راک
#
#                                          وضعیت رابطه  \
# 0                                رابطه های نا پایدار
# 1                               این بحث ها برام زوده
# 2               بدون رابطه ولی علاقمند به شروع رابطه
# 3  با کامپیوتر/اینترنت/برنامه نویسی/سیستم عامل/.....
# 4                                     ازدواج کرده ام
#
#    به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)  \
# 0                                                3.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                1.0
#
#                                   حوزه کاری شما چیست  \
# 0  توسعه دهنده فول استک وب, توسعه دهنده بک اند, ت...
# 1        توسعه دهنده فول استک وب, توسعه دهنده موبایل
# 2  توسعه دهنده بک اند, توسعه دهنده دسکتاپ, توسعه ...
# 3        توسعه دهنده فول استک وب, توسعه دهنده موبایل
# 4  توسعه دهنده فول استک وب, توسعه دهنده بک اند, م...
#
#                               نوع شرکت شما کدام است؟  \
# 0  بخش آی تی شرکت های غیر نرم افزاری (مانند مخابر...
# 1               شرکت های ارائه دهنده سرویس های مختلف
# 2  بخش آی تی شرکت های غیر نرم افزاری (مانند مخابر...
# 3                           شرکت های تولید نرم افزار
# 4     شرکت های ارائه دهنده سرویس های مختلف, استارتاپ
#
#    تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)  \
# 0                                                 40
# 1                                                 30
# 2                                                500
# 3                                                  1
# 4                                                  5
#
#   متوسط درآمد ماهیانه شما (به تومان)  \
# 0             سه و نیم تا پنج میلیون
# 1             سه و نیم تا پنج میلیون
# 2              دو تا سه و نیم میلیون
# 3              دو تا سه و نیم میلیون
# 4              دو تا سه و نیم میلیون
#
#         محل کار چه خدماتی بیشتر از حقوق ارائه می دهد چگونه کار می کنید؟  \
# 0  قهوه،‌ چای و ... رایگان, برگزاری مراسم و تولده...     تمام وقت خصوصی
# 1              قهوه،‌ چای و ... رایگان, لپ تاپ, بیمه     تمام وقت خصوصی
# 2  باشگاه ورزشی داخل شرکت, عضویت باشگاه های ورزشی...     تمام وقت خصوصی
# 3                                                NaN     پروژه ای مستقل
# 4  عضویت باشگاه های ورزشی یا هزینه ورزش, قهوه،‌ چ...     تمام وقت خصوصی
#
#               شیوه کار شما کدام است؟  \
# 0  تمام وقت‌های کاری را در دفتر هستم
# 1  تمام وقت‌های کاری را در دفتر هستم
# 2  تمام وقت‌های کاری را در دفتر هستم
# 3      شخصی کار می کنم و در محل خودم
# 4  تمام وقت‌های کاری را در دفتر هستم
#
#   در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)  \
# 0                            بین بیست و پنج تا پنجاه
# 1                                                NaN
# 2                                  ساعتی کار نمی کنم
# 3                                                NaN
# 4                                  ساعتی کار نمی کنم
#
#    چقدر از کاری که انتخاب کرده اید راضی هستید؟  \
# 0                                            4
# 1                                            4
# 2                                            5
# 3                                            5
# 4                                            3
#
#   آیا نکته ای هست که بخواهید اضافه کنید؟ بنویسید...
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN

# %%
df_95.columns
# Out:
# Index(['Timestamp', 'در کدام محدوده سنی هستید؟', 'جنسیت',
#        'خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (:',
#        'استان محل کار', 'چند سال تجربه کار تمام وقت دارید؟',
#        'آخرین وضعیت تحصیلی', 'چه مدارک بین المللی ای اخذ کرده اید',
#        'چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟',
#        'چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟',
#        'در سه ماه گذشته چند کتاب خوانده اید؟',
#        'زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟',
#        'به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟',
#        'دیتابیس‌های مورد استفاده', 'سیستم عامل رومیزی شما کدام است؟',
#        'سیستم عامل سرور مورد علاقه شما', 'و وقتی صحبت از تلفن همراه باشد...',
#        'در چه محیطی برنامه نویسی می‌کنید', 'تم آی دی ای',
#        'از چه سورس کنترلی استفاده می کنید؟',
#        'از کدام تکنولوزی ها استفاده می کنید', 'تب یا اسپیس؟',
#        'نوشیدنی‌های اصلی شما چیست؟', 'تیپ ', 'تغییر در بدن؟',
#        'کدام‌ها در مورد شما صدق می‌کند', 'سبک موسیقی', 'وضعیت رابطه',
#        'به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)',
#        'حوزه کاری شما چیست', 'نوع شرکت شما کدام است؟',
#        'تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)',
#        'متوسط درآمد ماهیانه شما (به تومان)',
#        'محل کار چه خدماتی بیشتر از حقوق ارائه می دهد', 'چگونه کار می کنید؟',
#        'شیوه کار شما کدام است؟',
#        'در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)',
#        'چقدر از کاری که انتخاب کرده اید راضی هستید؟',
#        'آیا نکته ای هست که بخواهید اضافه کنید؟ بنویسید...'],
#       dtype='object')

# %%
df_95.columns = ('time', 'age', 'gender', 'home_province', 'work_province', 'experience_years', 'education', 'international_certificates', 'learning_per_week', 'fun_projects_per_week', 'books_read_last_three_months', 'programming_languages', 'want_to_work_languages', 'database', 'desktop_os', 'server_os', 'mobile_os', 'ide', 'ide_theme', 'source_control', 'technology', 'tab_or_space', 'drinks', 'style_', 'change_in_body', 'about_you', 'music_style', 'relationship', 'how_many_devices', 'position', 'company_type', 'employees', 'avg_monthly_salary', 'company_benefits', 'work_type', 'work_way', 'wage_per_hour', 'satisfaction', 'comment')

# %%
df_95.head()
# Out:
#                  time       age gender home_province work_province  \
# 0  2/28/2017 17:44:04  ۲۳ تا ۲۹    مرد         تهران         تهران
# 1  2/28/2017 17:41:58  ۲۳ تا ۲۹    مرد         تهران         تهران
# 2  2/28/2017 17:45:04  ۲۳ تا ۲۹    مرد          فارس         تهران
# 3  2/28/2017 17:53:54  ۲۳ تا ۲۹    مرد         البرز         البرز
# 4  2/28/2017 17:57:19  ۲۳ تا ۲۹    مرد         البرز         تهران
#
#     experience_years                   education international_certificates  \
# 0  هفت تا پانزده سال                      لیسانس                        NaN
# 1      سه تا هفت سال  در حال تحصیل در فوق لیسانس                        NaN
# 2      سه تا هفت سال                      لیسانس                        NaN
# 3      سه تا هفت سال  در حال تحصیل در فوق لیسانس                        NaN
# 4       یک تا سه سال  در حال تحصیل در فوق لیسانس                        NaN
#
#     learning_per_week fun_projects_per_week books_read_last_three_months  \
# 0      دو تا هفت ساعت        دو تا هفت ساعت                          هیچ
# 1      دو تا هفت ساعت        دو تا هفت ساعت                     دو یا سه
# 2      دو تا هفت ساعت                   صفر                     سه تا شش
# 3  هفت تا چهارده ساعت        دو تا هفت ساعت                          هیچ
# 4      دو تا هفت ساعت                   صفر                           یک
#
#         programming_languages                     want_to_work_languages  \
# 0        PHP, Javascript, SQL                    Python, Ruby, Swift, Go
# 1  Java, PHP, Javascript, SQL                                      Swift
# 2   C#, Javascript, SQL, Bash                         Python, PHP, Swift
# 3       Java, PHP, Javascript                                 C#, Python
# 4        PHP, Javascript, SQL  Java, Python, PHP, Javascript, Swift, SQL
#
#                                     database  \
# 0  MySQL/MariaDB, Postgresql, MongoDB, Redis
# 1   MySQL/MariaDB, Postgresql, sqlite, Redis
# 2              MS-SQL, MySQL/MariaDB, Oracle
# 3                      MySQL/MariaDB, sqlite
# 4        No Database, MySQL/MariaDB, MongoDB
#
#                             desktop_os                          server_os  \
# 0                                 OS X         Linux Debian, Linux Ubuntu
# 1                                 OS X                       Linux CentOS
# 2  Windows 7, Windows 10, Linux Ubuntu  Windows Server 2012, Linux Debian
# 3                           Windows 10                       Linux CentOS
# 4       Windows 10, OS X, Linux Ubuntu                 Linux Ubuntu, os x
#
#       mobile_os                       ide ide_theme source_control  \
# 0           iOS              سابلایم, ویم      تیره            گیت
# 1  Android, iOS  سابلایم, محصولات جت برین      تیره            گیت
# 2       Android            ویژوال استودیو      تیره            گیت
# 3  Android, iOS           محصولات جت برین      تیره            گیت
# 4       Android            محصولات اکلیپس      تیره            گیت
#
#                                      technology  tab_or_space  \
# 0  سورس کنترل, کانتینرها, تست های خودکار, کلاود            تب
# 1                                    سورس کنترل            تب
# 2                                    سورس کنترل         اسپیس
# 3                                    سورس کنترل            تب
# 4                        سورس کنترل, هوش مصنوعی  تفاوتی ندارد
#
#                                               drinks  \
# 0  چای, قهوه, انرژی زا, نوشابه, انواع ماء الشعیر,...
# 1                                            چای, آب
# 2                        چای, قهوه, انرژی زا, نوشابه
# 3                                            چای, آب
# 4                                          چای, قهوه
#
#                                               style_ change_in_body  \
# 0  تی شرت, جین, پیرهن مردونه, گجت پوشیدنی دارم (س...            NaN
# 1                                       تیره, اسپورت            NaN
# 2               تی شرت, جین, رنگی رنگی, روشن, اسپورت            NaN
# 3  تی شرت, جین, پیرهن مردونه, ساعت می بندم, اسپور...            NaN
# 4                          تی شرت, جین, پیرهن مردونه            NaN
#
#                                            about_you  \
# 0  بیشتر از سه بار در هفته ورزش می کنم, سیاست برا...
# 1  بیشتر از یک نخ در روز سیگار می کشم, سیاست برای...
# 2                 در رابطه نیستم ولی دوست داشتم بودم
# 3                                                NaN
# 4  بیشتر از یک نخ در روز سیگار می کشم, حداقل یک ر...
#
#                          music_style  \
# 0                      الکترونیک دنس
# 1                 پاپ ایرانی, دامبول
# 2  پاپ ایرانی, پاپ خارجی, رپ, دامبول
# 3                                NaN
# 4               پاپ خارجی, متال, راک
#
#                                         relationship  how_many_devices  \
# 0                                رابطه های نا پایدار               3.0
# 1                               این بحث ها برام زوده               1.0
# 2               بدون رابطه ولی علاقمند به شروع رابطه               1.0
# 3  با کامپیوتر/اینترنت/برنامه نویسی/سیستم عامل/.....               NaN
# 4                                     ازدواج کرده ام               1.0
#
#                                             position  \
# 0  توسعه دهنده فول استک وب, توسعه دهنده بک اند, ت...
# 1        توسعه دهنده فول استک وب, توسعه دهنده موبایل
# 2  توسعه دهنده بک اند, توسعه دهنده دسکتاپ, توسعه ...
# 3        توسعه دهنده فول استک وب, توسعه دهنده موبایل
# 4  توسعه دهنده فول استک وب, توسعه دهنده بک اند, م...
#
#                                         company_type  employees  \
# 0  بخش آی تی شرکت های غیر نرم افزاری (مانند مخابر...         40
# 1               شرکت های ارائه دهنده سرویس های مختلف         30
# 2  بخش آی تی شرکت های غیر نرم افزاری (مانند مخابر...        500
# 3                           شرکت های تولید نرم افزار          1
# 4     شرکت های ارائه دهنده سرویس های مختلف, استارتاپ          5
#
#        avg_monthly_salary                                   company_benefits  \
# 0  سه و نیم تا پنج میلیون  قهوه،‌ چای و ... رایگان, برگزاری مراسم و تولده...
# 1  سه و نیم تا پنج میلیون              قهوه،‌ چای و ... رایگان, لپ تاپ, بیمه
# 2   دو تا سه و نیم میلیون  باشگاه ورزشی داخل شرکت, عضویت باشگاه های ورزشی...
# 3   دو تا سه و نیم میلیون                                                NaN
# 4   دو تا سه و نیم میلیون  عضویت باشگاه های ورزشی یا هزینه ورزش, قهوه،‌ چ...
#
#         work_type                           work_way            wage_per_hour  \
# 0  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم  بین بیست و پنج تا پنجاه
# 1  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم                      NaN
# 2  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 3  پروژه ای مستقل      شخصی کار می کنم و در محل خودم                      NaN
# 4  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
#
#    satisfaction comment
# 0             4     NaN
# 1             4     NaN
# 2             5     NaN
# 3             5     NaN
# 4             3     NaN

# %%
df_95.work_way.unique()
# Out:
# array(['تمام وقت\u200cهای کاری را در دفتر هستم',
#        'شخصی کار می کنم و در محل خودم',
#        'اکثر وقت\u200cها در دفتر ولی دورکاری هم می کنم', 'دورکاری کامل',
#        'اکثر مواقع دورکاری و گاهی به دفتر می روم', nan], dtype=object)

# %%
df_95.mobile_os.unique()
# Out:
# array(['iOS', 'Android, iOS', 'Android', 'iOS, Blackberry',
#        'Android, iOS, Windows Phone', 'Phone? I dont carry a phone!',
#        'Android, Dump phones (1100, ...)', 'Java / Symbian / Maemo / ...',
#        'Android, Blackberry', 'Android, Windows Phone', 'Windows Phone',
#        'Android, Phone? I dont carry a phone!', 'Blackberry',
#        'iOS, Windows Phone', 'Blackberry, Dump phones (1100, ...)',
#        'iOS, Dump phones (1100, ...)',
#        'Android, iOS, Dump phones (1100, ...)',
#        'Android, iOS, Windows Phone, Blackberry',
#        'Android, iOS, Blackberry', 'Dump phones (1100, ...)', nan,
#        'Android, Java / Symbian / Maemo / ..., Dump phones (1100, ...)',
#        'Windows Phone, Blackberry',
#        'Android, iOS, Windows Phone, Java / Symbian / Maemo / ...',
#        'Android, iOS, Windows Phone, Java / Symbian / Maemo / ..., Blackberry, Dump phones (1100, ...), Phone? I dont carry a phone!',
#        'Android, Java / Symbian / Maemo / ...'], dtype=object)

# %%
df_95.fillna("هیچکدام", inplace=True)


df_95['programming_languages'] = df_95.programming_languages.apply(lambda x: x.split(','))
df_95['want_to_work_languages'] = df_95.want_to_work_languages.apply(lambda x: x.split(','))
df_95['database'] = df_95.database.apply(lambda x: x.split(','))
df_95['desktop_os'] = df_95.desktop_os.apply(lambda x: x.split(','))
df_95['server_os'] = df_95.server_os.apply(lambda x: x.split(','))

df_95['mobile_os'] = df_95.mobile_os.str.replace("Dump phones \(1100, ...\)", "Dump phones")
df_95['mobile_os'] = df_95.mobile_os.apply(lambda x: x.split(','))

df_95['ide'] = df_95.ide.apply(lambda x: x.split(','))
df_95['source_control'] = df_95.source_control.apply(lambda x: x.split(','))
df_95['technology'] = df_95.technology.apply(lambda x: x.split(','))
df_95['drinks'] = df_95.drinks.apply(lambda x: x.split(','))
df_95['style_'] = df_95.style_.apply(lambda x: x.split(','))
df_95['change_in_body'] = df_95.change_in_body.apply(lambda x: x.split(','))
df_95['music_style'] = df_95.music_style.apply(lambda x: x.split(','))
df_95['position'] = df_95.position.apply(lambda x: x.split(','))
df_95['company_type'] = df_95.company_type.apply(lambda x: x.split(','))
df_95['company_benefits'] = df_95.company_benefits.apply(lambda x: x.split(','))
df_95['style'] = df_95.style.apply(lambda x: x.split(','))
df_95['about_you'] = df_95.about_you.apply(lambda x: x.split(','))

df_95.head()
# Out:
#                  time       age gender home_province work_province  \
# 0  2/28/2017 17:44:04  ۲۳ تا ۲۹    مرد         تهران         تهران
# 1  2/28/2017 17:41:58  ۲۳ تا ۲۹    مرد         تهران         تهران
# 2  2/28/2017 17:45:04  ۲۳ تا ۲۹    مرد          فارس         تهران
# 3  2/28/2017 17:53:54  ۲۳ تا ۲۹    مرد         البرز         البرز
# 4  2/28/2017 17:57:19  ۲۳ تا ۲۹    مرد         البرز         تهران
#
#     experience_years                   education international_certificates  \
# 0  هفت تا پانزده سال                      لیسانس                    هیچکدام
# 1      سه تا هفت سال  در حال تحصیل در فوق لیسانس                    هیچکدام
# 2      سه تا هفت سال                      لیسانس                    هیچکدام
# 3      سه تا هفت سال  در حال تحصیل در فوق لیسانس                    هیچکدام
# 4       یک تا سه سال  در حال تحصیل در فوق لیسانس                    هیچکدام
#
#     learning_per_week fun_projects_per_week books_read_last_three_months  \
# 0      دو تا هفت ساعت        دو تا هفت ساعت                          هیچ
# 1      دو تا هفت ساعت        دو تا هفت ساعت                     دو یا سه
# 2      دو تا هفت ساعت                   صفر                     سه تا شش
# 3  هفت تا چهارده ساعت        دو تا هفت ساعت                          هیچ
# 4      دو تا هفت ساعت                   صفر                           یک
#
#              programming_languages  \
# 0         [PHP,  Javascript,  SQL]
# 1  [Java,  PHP,  Javascript,  SQL]
# 2   [C#,  Javascript,  SQL,  Bash]
# 3        [Java,  PHP,  Javascript]
# 4         [PHP,  Javascript,  SQL]
#
#                              want_to_work_languages  \
# 0                      [Python,  Ruby,  Swift,  Go]
# 1                                           [Swift]
# 2                            [Python,  PHP,  Swift]
# 3                                     [C#,  Python]
# 4  [Java,  Python,  PHP,  Javascript,  Swift,  SQL]
#
#                                          database  \
# 0  [MySQL/MariaDB,  Postgresql,  MongoDB,  Redis]
# 1   [MySQL/MariaDB,  Postgresql,  sqlite,  Redis]
# 2               [MS-SQL,  MySQL/MariaDB,  Oracle]
# 3                        [MySQL/MariaDB,  sqlite]
# 4         [No Database,  MySQL/MariaDB,  MongoDB]
#
#                                 desktop_os  \
# 0                                   [OS X]
# 1                                   [OS X]
# 2  [Windows 7,  Windows 10,  Linux Ubuntu]
# 3                             [Windows 10]
# 4       [Windows 10,  OS X,  Linux Ubuntu]
#
#                               server_os        mobile_os  \
# 0         [Linux Debian,  Linux Ubuntu]            [iOS]
# 1                        [Linux CentOS]  [Android,  iOS]
# 2  [Windows Server 2012,  Linux Debian]        [Android]
# 3                        [Linux CentOS]  [Android,  iOS]
# 4                 [Linux Ubuntu,  os x]        [Android]
#
#                            ide ide_theme source_control  \
# 0              [سابلایم,  ویم]      تیره          [گیت]
# 1  [سابلایم,  محصولات جت برین]      تیره          [گیت]
# 2             [ویژوال استودیو]      تیره          [گیت]
# 3            [محصولات جت برین]      تیره          [گیت]
# 4             [محصولات اکلیپس]      تیره          [گیت]
#
#                                           technology  tab_or_space  \
# 0  [سورس کنترل,  کانتینرها,  تست های خودکار,  کلاود]            تب
# 1                                       [سورس کنترل]            تب
# 2                                       [سورس کنترل]         اسپیس
# 3                                       [سورس کنترل]            تب
# 4                          [سورس کنترل,  هوش مصنوعی]  تفاوتی ندارد
#
#                                               drinks  \
# 0  [چای,  قهوه,  انرژی زا,  نوشابه,  انواع ماء ال...
# 1                                         [چای,  آب]
# 2                   [چای,  قهوه,  انرژی زا,  نوشابه]
# 3                                         [چای,  آب]
# 4                                       [چای,  قهوه]
#
#                                               style_ change_in_body  \
# 0  [تی شرت,  جین,  پیرهن مردونه,  گجت پوشیدنی دار...      [هیچکدام]
# 1                                    [تیره,  اسپورت]      [هیچکدام]
# 2         [تی شرت,  جین,  رنگی رنگی,  روشن,  اسپورت]      [هیچکدام]
# 3  [تی شرت,  جین,  پیرهن مردونه,  ساعت می بندم,  ...      [هیچکدام]
# 4                      [تی شرت,  جین,  پیرهن مردونه]      [هیچکدام]
#
#                                            about_you  \
# 0  [بیشتر از سه بار در هفته ورزش می کنم,  سیاست ب...
# 1  [بیشتر از یک نخ در روز سیگار می کشم,  سیاست بر...
# 2               [در رابطه نیستم ولی دوست داشتم بودم]
# 3                                          [هیچکدام]
# 4  [بیشتر از یک نخ در روز سیگار می کشم,  حداقل یک...
#
#                               music_style  \
# 0                         [الکترونیک دنس]
# 1                   [پاپ ایرانی,  دامبول]
# 2  [پاپ ایرانی,  پاپ خارجی,  رپ,  دامبول]
# 3                               [هیچکدام]
# 4                [پاپ خارجی,  متال,  راک]
#
#                                         relationship how_many_devices  \
# 0                                رابطه های نا پایدار                3
# 1                               این بحث ها برام زوده                1
# 2               بدون رابطه ولی علاقمند به شروع رابطه                1
# 3  با کامپیوتر/اینترنت/برنامه نویسی/سیستم عامل/.....          هیچکدام
# 4                                     ازدواج کرده ام                1
#
#                                             position  \
# 0  [توسعه دهنده فول استک وب,  توسعه دهنده بک اند,...
# 1     [توسعه دهنده فول استک وب,  توسعه دهنده موبایل]
# 2  [توسعه دهنده بک اند,  توسعه دهنده دسکتاپ,  توس...
# 3     [توسعه دهنده فول استک وب,  توسعه دهنده موبایل]
# 4  [توسعه دهنده فول استک وب,  توسعه دهنده بک اند,...
#
#                                         company_type  employees  \
# 0  [بخش آی تی شرکت های غیر نرم افزاری (مانند مخاب...         40
# 1             [شرکت های ارائه دهنده سرویس های مختلف]         30
# 2  [بخش آی تی شرکت های غیر نرم افزاری (مانند مخاب...        500
# 3                         [شرکت های تولید نرم افزار]          1
# 4  [شرکت های ارائه دهنده سرویس های مختلف,  استارتاپ]          5
#
#        avg_monthly_salary                                   company_benefits  \
# 0  سه و نیم تا پنج میلیون  [قهوه،‌ چای و ... رایگان,  برگزاری مراسم و تول...
# 1  سه و نیم تا پنج میلیون          [قهوه،‌ چای و ... رایگان,  لپ تاپ,  بیمه]
# 2   دو تا سه و نیم میلیون  [باشگاه ورزشی داخل شرکت,  عضویت باشگاه های ورز...
# 3   دو تا سه و نیم میلیون                                          [هیچکدام]
# 4   دو تا سه و نیم میلیون  [عضویت باشگاه های ورزشی یا هزینه ورزش,  قهوه،‌...
#
#         work_type                           work_way            wage_per_hour  \
# 0  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم  بین بیست و پنج تا پنجاه
# 1  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم                  هیچکدام
# 2  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 3  پروژه ای مستقل      شخصی کار می کنم و در محل خودم                  هیچکدام
# 4  تمام وقت خصوصی  تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
#
#    satisfaction  comment                                              style
# 0             4  هیچکدام  <pandas.io.formats.style.Styler object at 0x7f...
# 1             4  هیچکدام  <pandas.io.formats.style.Styler object at 0x7f...
# 2             5  هیچکدام  <pandas.io.formats.style.Styler object at 0x7f...
# 3             5  هیچکدام  <pandas.io.formats.style.Styler object at 0x7f...
# 4             3  هیچکدام  <pandas.io.formats.style.Styler object at 0x7f...

# %%
df_96 = pd.read_csv('data/1396.csv')
df_96.head()
# Out:
#                          Timestamp در کدام محدوده سنی هستید؟ جنسیت  \
# 0  2018/02/13 12:16:39 PM GMT+4:30                  ۳۰ تا ۳۹   مرد
# 1  2018/02/13 12:16:44 PM GMT+4:30                  ۲۳ تا ۲۹   مرد
# 2  2018/02/13 12:19:42 PM GMT+4:30                  ۲۳ تا ۲۹    زن
# 3  2018/02/13 12:20:11 PM GMT+4:30                  ۲۳ تا ۲۹   مرد
# 4  2018/02/13 12:21:54 PM GMT+4:30                  ۲۳ تا ۲۹   مرد
#
#   خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (: استان محل کار  \
# 0                                              تهران             تهران
# 1                                              کرمان             تهران
# 2                                              همدان             تهران
# 3                                              تهران             تهران
# 4                                                یزد               یزد
#
#   چند سال تجربه کار تمام وقت دارید؟ آخرین وضعیت تحصیلی  \
# 0              پانزده تا بیست و پنج             لیسانس
# 1                      یک تا سه سال         فوق لیسانس
# 2                         زیر یکسال             لیسانس
# 3                     سه تا هفت سال             لیسانس
# 4                      یک تا سه سال             لیسانس
#
#   چه مدارک بین المللی ای اخذ کرده اید  \
# 0  Management (PMP, SCRUM, ITIL, ...)
# 1                                 NaN
# 2                                 NaN
# 3                   Linux (LPIC, ...)
# 4                                 NaN
#
#   چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟  \
# 0                                     دو تا هفت ساعت
# 1                                    کمتر از دو ساعت
# 2                                    کمتر از دو ساعت
# 3                                     دو تا هفت ساعت
# 4                               بیشتر از چهارده ساعت
#
#            بیشترین یادگیری شما در کجا اتفاق می افتد؟  \
# 0  سایت‌های آموزش آنلاین خارجی;کتاب / خودآموزهای ...
# 1  سایت‌های آموزش آنلاین خارجی;کتاب / خودآموزهای ...
# 2  ویدئوهای مستقل آموزشی;یادگیری از طریق انجام پروژه
# 3                              ویدئوهای مستقل آموزشی
# 4                        یادگیری از طریق انجام پروژه
#
#   چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟  \
# 0                                    کمتر از دو ساعت
# 1                                     دو تا هفت ساعت
# 2                                                صفر
# 3                                    کمتر از دو ساعت
# 4                                 هفت تا چهارده ساعت
#
#   در سه ماه گذشته چند کتاب [غیردرسی] خوانده اید؟  \
# 0                                       سه تا شش
# 1                                       دو یا سه
# 2                                       دو یا سه
# 3                                       دو یا سه
# 4                                             یک
#
#   زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟  \
# 0                               برنامه نویسی نمی‌کنم
# 1                                     PHP;Javascript
# 2                                                 C#
# 3                                               Bash
# 4                                 PHP;Javascript;SQL
#
#   به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟  \
# 0                                               Bash
# 1                       Python;Javascript;Go;Haskell
# 2                                         Javascript
# 3                                             Python
# 4                                             Python
#
#       دیتابیس‌های مورد استفاده سیستم عامل رومیزی شما کدام است؟  \
# 0                  No Database                            OS X
# 1                MySQL/MariaDB                      Linux Arch
# 2                MS-SQL;Oracle                      Windows 10
# 3                MySQL/MariaDB                    Linux Debian
# 4  MySQL/MariaDB;MongoDB;Redis                    Linux Ubuntu
#
#   سیستم عامل سرور مورد علاقه شما    و وقتی صحبت از تلفن همراه باشد...  \
# 0                   Linux CentOS  Android;iOS;Dumb phones (1100, ...)
# 1                   Linux CentOS                                  iOS
# 2            Windows Server 2016                              Android
# 3                   Linux Debian                              Android
# 4                   Linux Debian                              Android
#
#                     در چه محیطی برنامه نویسی می‌کنید          تم آی دی ای  \
# 0  سابلایم;اتم;ادیتورهای متن ساده (نوت پد پلاس پل...                 تیره
# 1  سابلایم;ادیتورهای متن ساده (نوت پد پلاس پلاس، ...                 تیره
# 2                                     ویژوال استودیو                 روشن
# 3                                             mcedit  گاهی روشن گاهی تیره
# 4                                    محصولات جت برین                 تیره
#
#   از چه سورس کنترلی استفاده می کنید؟  \
# 0                                گیت
# 1                                گیت
# 2                       گیت;اس وی ان
# 3                                گیت
# 4                                گیت
#
#                  از کدام تکنولوزی ها استفاده می کنید  \
# 0                 سورس کنترل;ویکی‌های مربوط به پروژه
# 1                                         سورس کنترل
# 2                                   سورس کنترل;کلاود
# 3  سورس کنترل;کانتینرها;بیلد سیستم ها;تست های خود...
# 4  سورس کنترل;کانتینرها;بیلد سیستم ها;ویکی‌های مر...
#
#            کدام سرویس برای شما بسیار پر استفاده است؟ تب یا اسپیس؟  \
# 0  ترلو;تودولیست‌ها;اسلک;ابزارهای مدیریت پروژه ات...           تب
# 1                       استک اورفلو;ترلو;تسکولو;اسلک        اسپیس
# 2  استک اورفلو;ترلو;ابزارهای مدیریت پروژه مایکروسافت           تب
# 3                       استک اورفلو;تودولیست‌ها;اسلک           تب
# 4                                   استک اورفلو;ترلو           تب
#
#                     نوشیدنی‌های مورد علاقه شما چیست؟  \
# 0   چای سیاه;قهوه;انواع ماء الشعیر;نوشیدنی‌های الکلی
# 1  چای سیاه;قهوه;انرژی زا;نوشابه;انواع ماء الشعیر...
# 2  چای سیاه;قهوه;دمنوش‌های متنوع;انرژی زا;نوشابه;...
# 3  چای سیاه;دمنوش‌های متنوع;انرژی زا;نوشیدنی‌های ...
# 4                                                 آب
#
#                                                 تیپ  تغییر در بدن؟  \
# 0  تی شرت;جین;پیرهن مردونه;رسمی;گجت پوشیدنی دارم ...           NaN
# 1                   تی شرت;جین;پیرهن مردونه;شال;تیره           NaN
# 2                           جین;شال;رنگی رنگی;اسپورت           NaN
# 3     تی شرت;جین;گجت پوشیدنی دارم (ساعت هوشمند، ...)           NaN
# 4                                   جین;پیرهن مردونه           NaN
#
#                       کدام‌ها در مورد شما صدق می‌کند  \
# 0  بیشتر از یک نخ در روز سیگار می کشم;سیاست برایم...
# 1  بیشتر از یک نخ در روز سیگار می کشم;سیاست برایم...
# 2  بیشتر از یک نخ در روز سیگار می کشم;حداقل یک رو...
# 3  در رابطه نیستم ولی دوست داشتم بودم;حداقل یک رو...
# 4  به شکل مرتب نماز می‌خونم;بیشتر از سه بار در هف...
#
#                                   سبک موسیقی  \
# 0  کلاسیک;سنتی;پاپ ایرانی;دامبول;بلوز;کانتری
# 1                        سنتی;پاپ ایرانی;راک
# 2                کلاسیک;سنتی;پاپ ایرانی;بلوز
# 3       پاپ خارجی;متال;easy listening;دامبول
# 4                                       سنتی
#
#                                          وضعیت رابطه  \
# 0                                     ازدواج کرده ام
# 1                                رابطه های نا پایدار
# 2                                     ازدواج کرده ام
# 3  با کامپیوتر/اینترنت/برنامه نویسی/سیستم عامل/.....
# 4               بدون رابطه ولی علاقمند به شروع رابطه
#
#    به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)  \
# 0                                                4.0
# 1                                                2.0
# 2                                                1.0
# 3                                                NaN
# 4                                                1.0
#
#         حوزه کاری شما چیست                             نوع شرکت شما کدام است؟  \
# 0  مدیر شرکت / پروژه / ...  بخش آی تی شرکت های غیر نرم افزاری (مانند مخابر...
# 1       توسعه دهنده بک اند                                 بخش دولتی;استارتاپ
# 2       توسعه دهنده بک اند                           شرکت های تولید نرم افزار
# 3  مدیر سیستم;مدیر دیتابیس                                           استارتاپ
# 4  توسعه دهنده فول استک وب                                                NaN
#
#    تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)  \
# 0                                              200.0
# 1                                               14.0
# 2                                              100.0
# 3                                               20.0
# 4                                                1.0
#
#   متوسط درآمد ماهیانه شما (به تومان)  \
# 0                  پنج تا هفت میلیون
# 1              دو تا سه و نیم میلیون
# 2                    یک تا دو میلیون
# 3              دو تا سه و نیم میلیون
# 4                    یک تا دو میلیون
#
#         محل کار چه خدماتی بیشتر از حقوق ارائه می دهد  \
# 0  باشگاه ورزشی داخل شرکت;قهوه،‌ چای و ... رایگان...
# 1               ناهار رایگان;قهوه،‌ چای و ... رایگان
# 2  قهوه،‌ چای و ... رایگان;کارت هدیه و کارت خرید;...
# 3  ناهار رایگان;قهوه،‌ چای و ... رایگان;برگزاری م...
# 4                                                NaN
#
#                              چگونه کار می کنید؟  \
# 0  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 1  نیمه وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 2  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 3  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 4                                پروژه ای مستقل
#
#                      شیوه کار شما کدام است؟  \
# 0         تمام وقت‌های کاری را در دفتر هستم
# 1  اکثر مواقع دورکاری و گاهی به دفتر می روم
# 2         تمام وقت‌های کاری را در دفتر هستم
# 3         تمام وقت‌های کاری را در دفتر هستم
# 4             شخصی کار می کنم و در محل خودم
#
#   در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)  \
# 0                                  ساعتی کار نمی کنم
# 1                            بین بیست و پنج تا پنجاه
# 2                                  ساعتی کار نمی کنم
# 3                                  ساعتی کار نمی کنم
# 4                            بین بیست و پنج تا پنجاه
#
#    چقدر از کاری که انتخاب کرده اید راضی هستید؟  \
# 0                                            4
# 1                                            4
# 2                                            3
# 3                                            4
# 4                                            3
#
#   آیا برنامه نویسی یا مدیریت سیستم‌ها شغل اصلی شماست؟
# 0                                                خیر
# 1                                                بله
# 2                                                بله
# 3                                                بله
# 4                                                بله

# %%
df_96.columns
# Out:
# Index(['Timestamp', 'در کدام محدوده سنی هستید؟', 'جنسیت',
#        'خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (:',
#        'استان محل کار', 'چند سال تجربه کار تمام وقت دارید؟',
#        'آخرین وضعیت تحصیلی', 'چه مدارک بین المللی ای اخذ کرده اید',
#        'چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟',
#        'بیشترین یادگیری شما در کجا اتفاق می افتد؟',
#        'چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟',
#        'در سه ماه گذشته چند کتاب [غیردرسی] خوانده اید؟',
#        'زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟',
#        'به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟',
#        'دیتابیس‌های مورد استفاده', 'سیستم عامل رومیزی شما کدام است؟',
#        'سیستم عامل سرور مورد علاقه شما', 'و وقتی صحبت از تلفن همراه باشد...',
#        'در چه محیطی برنامه نویسی می‌کنید', 'تم آی دی ای',
#        'از چه سورس کنترلی استفاده می کنید؟',
#        'از کدام تکنولوزی ها استفاده می کنید',
#        'کدام سرویس برای شما بسیار پر استفاده است؟', 'تب یا اسپیس؟',
#        'نوشیدنی‌های مورد علاقه شما چیست؟', 'تیپ ', 'تغییر در بدن؟',
#        'کدام‌ها در مورد شما صدق می‌کند', 'سبک موسیقی', 'وضعیت رابطه',
#        'به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)',
#        'حوزه کاری شما چیست', 'نوع شرکت شما کدام است؟',
#        'تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)',
#        'متوسط درآمد ماهیانه شما (به تومان)',
#        'محل کار چه خدماتی بیشتر از حقوق ارائه می دهد', 'چگونه کار می کنید؟',
#        'شیوه کار شما کدام است؟',
#        'در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)',
#        'چقدر از کاری که انتخاب کرده اید راضی هستید؟',
#        'آیا برنامه نویسی یا مدیریت سیستم‌ها شغل اصلی شماست؟'],
#       dtype='object')

# %%
df_96.columns = ('time', 'age', 'gender', 'home_province', 'work_province', 'experience_years', 'education', 'international_certificates', 'learning_per_week', 'where_do_you_learn', 'fun_projects_per_week', 'books_read_last_three_months', 'programming_languages', 'want_to_work_languages', 'database', 'desktop_os', 'server_os', 'mobile_os', 'ide', 'ide_theme', 'source_control', 'technology', 'most_used_service', 'tab_or_space', 'drinks', 'style_', 'change_in_body', 'about_you', 'music_style', 'relationship', 'how_many_devices', 'position', 'company_type', 'employees', 'avg_monthly_salary', 'company_benefits', 'work_type', 'work_way', 'wage_per_hour', 'satisfaction', 'is_programming_your_main_job')

# %%
df_96.head()
# Out:
#                               time       age gender home_province  \
# 0  2018/02/13 12:16:39 PM GMT+4:30  ۳۰ تا ۳۹    مرد         تهران
# 1  2018/02/13 12:16:44 PM GMT+4:30  ۲۳ تا ۲۹    مرد         کرمان
# 2  2018/02/13 12:19:42 PM GMT+4:30  ۲۳ تا ۲۹     زن         همدان
# 3  2018/02/13 12:20:11 PM GMT+4:30  ۲۳ تا ۲۹    مرد         تهران
# 4  2018/02/13 12:21:54 PM GMT+4:30  ۲۳ تا ۲۹    مرد           یزد
#
#   work_province      experience_years   education  \
# 0         تهران  پانزده تا بیست و پنج      لیسانس
# 1         تهران          یک تا سه سال  فوق لیسانس
# 2         تهران             زیر یکسال      لیسانس
# 3         تهران         سه تا هفت سال      لیسانس
# 4           یزد          یک تا سه سال      لیسانس
#
#            international_certificates     learning_per_week  \
# 0  Management (PMP, SCRUM, ITIL, ...)        دو تا هفت ساعت
# 1                                 NaN       کمتر از دو ساعت
# 2                                 NaN       کمتر از دو ساعت
# 3                   Linux (LPIC, ...)        دو تا هفت ساعت
# 4                                 NaN  بیشتر از چهارده ساعت
#
#                                   where_do_you_learn fun_projects_per_week  \
# 0  سایت‌های آموزش آنلاین خارجی;کتاب / خودآموزهای ...       کمتر از دو ساعت
# 1  سایت‌های آموزش آنلاین خارجی;کتاب / خودآموزهای ...        دو تا هفت ساعت
# 2  ویدئوهای مستقل آموزشی;یادگیری از طریق انجام پروژه                   صفر
# 3                              ویدئوهای مستقل آموزشی       کمتر از دو ساعت
# 4                        یادگیری از طریق انجام پروژه    هفت تا چهارده ساعت
#
#   books_read_last_three_months programming_languages  \
# 0                     سه تا شش  برنامه نویسی نمی‌کنم
# 1                     دو یا سه        PHP;Javascript
# 2                     دو یا سه                    C#
# 3                     دو یا سه                  Bash
# 4                           یک    PHP;Javascript;SQL
#
#          want_to_work_languages                     database    desktop_os  \
# 0                          Bash                  No Database          OS X
# 1  Python;Javascript;Go;Haskell                MySQL/MariaDB    Linux Arch
# 2                    Javascript                MS-SQL;Oracle    Windows 10
# 3                        Python                MySQL/MariaDB  Linux Debian
# 4                        Python  MySQL/MariaDB;MongoDB;Redis  Linux Ubuntu
#
#              server_os                            mobile_os  \
# 0         Linux CentOS  Android;iOS;Dumb phones (1100, ...)
# 1         Linux CentOS                                  iOS
# 2  Windows Server 2016                              Android
# 3         Linux Debian                              Android
# 4         Linux Debian                              Android
#
#                                                  ide            ide_theme  \
# 0  سابلایم;اتم;ادیتورهای متن ساده (نوت پد پلاس پل...                 تیره
# 1  سابلایم;ادیتورهای متن ساده (نوت پد پلاس پلاس، ...                 تیره
# 2                                     ویژوال استودیو                 روشن
# 3                                             mcedit  گاهی روشن گاهی تیره
# 4                                    محصولات جت برین                 تیره
#
#   source_control                                         technology  \
# 0            گیت                 سورس کنترل;ویکی‌های مربوط به پروژه
# 1            گیت                                         سورس کنترل
# 2   گیت;اس وی ان                                   سورس کنترل;کلاود
# 3            گیت  سورس کنترل;کانتینرها;بیلد سیستم ها;تست های خود...
# 4            گیت  سورس کنترل;کانتینرها;بیلد سیستم ها;ویکی‌های مر...
#
#                                    most_used_service tab_or_space  \
# 0  ترلو;تودولیست‌ها;اسلک;ابزارهای مدیریت پروژه ات...           تب
# 1                       استک اورفلو;ترلو;تسکولو;اسلک        اسپیس
# 2  استک اورفلو;ترلو;ابزارهای مدیریت پروژه مایکروسافت           تب
# 3                       استک اورفلو;تودولیست‌ها;اسلک           تب
# 4                                   استک اورفلو;ترلو           تب
#
#                                               drinks  \
# 0   چای سیاه;قهوه;انواع ماء الشعیر;نوشیدنی‌های الکلی
# 1  چای سیاه;قهوه;انرژی زا;نوشابه;انواع ماء الشعیر...
# 2  چای سیاه;قهوه;دمنوش‌های متنوع;انرژی زا;نوشابه;...
# 3  چای سیاه;دمنوش‌های متنوع;انرژی زا;نوشیدنی‌های ...
# 4                                                 آب
#
#                                               style_ change_in_body  \
# 0  تی شرت;جین;پیرهن مردونه;رسمی;گجت پوشیدنی دارم ...            NaN
# 1                   تی شرت;جین;پیرهن مردونه;شال;تیره            NaN
# 2                           جین;شال;رنگی رنگی;اسپورت            NaN
# 3     تی شرت;جین;گجت پوشیدنی دارم (ساعت هوشمند، ...)            NaN
# 4                                   جین;پیرهن مردونه            NaN
#
#                                            about_you  \
# 0  بیشتر از یک نخ در روز سیگار می کشم;سیاست برایم...
# 1  بیشتر از یک نخ در روز سیگار می کشم;سیاست برایم...
# 2  بیشتر از یک نخ در روز سیگار می کشم;حداقل یک رو...
# 3  در رابطه نیستم ولی دوست داشتم بودم;حداقل یک رو...
# 4  به شکل مرتب نماز می‌خونم;بیشتر از سه بار در هف...
#
#                                  music_style  \
# 0  کلاسیک;سنتی;پاپ ایرانی;دامبول;بلوز;کانتری
# 1                        سنتی;پاپ ایرانی;راک
# 2                کلاسیک;سنتی;پاپ ایرانی;بلوز
# 3       پاپ خارجی;متال;easy listening;دامبول
# 4                                       سنتی
#
#                                         relationship  how_many_devices  \
# 0                                     ازدواج کرده ام               4.0
# 1                                رابطه های نا پایدار               2.0
# 2                                     ازدواج کرده ام               1.0
# 3  با کامپیوتر/اینترنت/برنامه نویسی/سیستم عامل/.....               NaN
# 4               بدون رابطه ولی علاقمند به شروع رابطه               1.0
#
#                   position                                       company_type  \
# 0  مدیر شرکت / پروژه / ...  بخش آی تی شرکت های غیر نرم افزاری (مانند مخابر...
# 1       توسعه دهنده بک اند                                 بخش دولتی;استارتاپ
# 2       توسعه دهنده بک اند                           شرکت های تولید نرم افزار
# 3  مدیر سیستم;مدیر دیتابیس                                           استارتاپ
# 4  توسعه دهنده فول استک وب                                                NaN
#
#    employees     avg_monthly_salary  \
# 0      200.0      پنج تا هفت میلیون
# 1       14.0  دو تا سه و نیم میلیون
# 2      100.0        یک تا دو میلیون
# 3       20.0  دو تا سه و نیم میلیون
# 4        1.0        یک تا دو میلیون
#
#                                     company_benefits  \
# 0  باشگاه ورزشی داخل شرکت;قهوه،‌ چای و ... رایگان...
# 1               ناهار رایگان;قهوه،‌ چای و ... رایگان
# 2  قهوه،‌ چای و ... رایگان;کارت هدیه و کارت خرید;...
# 3  ناهار رایگان;قهوه،‌ چای و ... رایگان;برگزاری م...
# 4                                                NaN
#
#                                       work_type  \
# 0  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 1  نیمه وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 2  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 3  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 4                                پروژه ای مستقل
#
#                                    work_way            wage_per_hour  \
# 0         تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 1  اکثر مواقع دورکاری و گاهی به دفتر می روم  بین بیست و پنج تا پنجاه
# 2         تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 3         تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 4             شخصی کار می کنم و در محل خودم  بین بیست و پنج تا پنجاه
#
#    satisfaction is_programming_your_main_job
# 0             4                          خیر
# 1             4                          بله
# 2             3                          بله
# 3             4                          بله
# 4             3                          بله

# %%
df_96.fillna("هیچکدام", inplace=True)


df_96['programming_languages'] = df_96.programming_languages.apply(lambda x: x.split(';'))
df_96['want_to_work_languages'] = df_96.want_to_work_languages.apply(lambda x: x.split(';'))
df_96['database'] = df_96.database.apply(lambda x: x.split(';'))
df_96['desktop_os'] = df_96.desktop_os.apply(lambda x: x.split(';'))
df_96['server_os'] = df_96.server_os.apply(lambda x: x.split(';'))

df_96['mobile_os'] = df_96.mobile_os.str.replace("Dump phones \(1100, ...\)", "Dump phones")
df_96['mobile_os'] = df_96.mobile_os.apply(lambda x: x.split(';'))

df_96['ide'] = df_96.ide.apply(lambda x: x.split(';'))
df_96['source_control'] = df_96.source_control.apply(lambda x: x.split(';'))
df_96['technology'] = df_96.technology.apply(lambda x: x.split(';'))
df_96['drinks'] = df_96.drinks.apply(lambda x: x.split(';'))
df_96['style'] = df_96.style.apply(lambda x: x.split(';'))
df_96['change_in_body'] = df_96.change_in_body.apply(lambda x: x.split(';'))
df_96['music_style'] = df_96.music_style.apply(lambda x: x.split(';'))
df_96['position'] = df_96.position.apply(lambda x: x.split(';'))
df_96['company_type'] = df_96.company_type.apply(lambda x: x.split(';'))
df_96['company_benefits'] = df_96.company_benefits.apply(lambda x: x.split(';'))
df_96['style_'] = df_96.style_.apply(lambda x: x.split(';'))
df_96['where_do_you_learn'] = df_96.where_do_you_learn.apply(lambda x: x.split(';'))
df_96['most_used_service'] = df_96.most_used_service.apply(lambda x: x.split(';'))
df_96['about_you'] = df_96.about_you.apply(lambda x: x.split(';'))

df_96.head()
# Out:
#                               time       age gender home_province  \
# 0  2018/02/13 12:16:39 PM GMT+4:30  ۳۰ تا ۳۹    مرد         تهران
# 1  2018/02/13 12:16:44 PM GMT+4:30  ۲۳ تا ۲۹    مرد         کرمان
# 2  2018/02/13 12:19:42 PM GMT+4:30  ۲۳ تا ۲۹     زن         همدان
# 3  2018/02/13 12:20:11 PM GMT+4:30  ۲۳ تا ۲۹    مرد         تهران
# 4  2018/02/13 12:21:54 PM GMT+4:30  ۲۳ تا ۲۹    مرد           یزد
#
#   work_province      experience_years   education  \
# 0         تهران  پانزده تا بیست و پنج      لیسانس
# 1         تهران          یک تا سه سال  فوق لیسانس
# 2         تهران             زیر یکسال      لیسانس
# 3         تهران         سه تا هفت سال      لیسانس
# 4           یزد          یک تا سه سال      لیسانس
#
#            international_certificates     learning_per_week  \
# 0  Management (PMP, SCRUM, ITIL, ...)        دو تا هفت ساعت
# 1                             هیچکدام       کمتر از دو ساعت
# 2                             هیچکدام       کمتر از دو ساعت
# 3                   Linux (LPIC, ...)        دو تا هفت ساعت
# 4                             هیچکدام  بیشتر از چهارده ساعت
#
#                                   where_do_you_learn fun_projects_per_week  \
# 0  [سایت‌های آموزش آنلاین خارجی, کتاب / خودآموزها...       کمتر از دو ساعت
# 1  [سایت‌های آموزش آنلاین خارجی, کتاب / خودآموزها...        دو تا هفت ساعت
# 2  [ویدئوهای مستقل آموزشی, یادگیری از طریق انجام ...                   صفر
# 3                            [ویدئوهای مستقل آموزشی]       کمتر از دو ساعت
# 4                      [یادگیری از طریق انجام پروژه]    هفت تا چهارده ساعت
#
#   books_read_last_three_months   programming_languages  \
# 0                     سه تا شش  [برنامه نویسی نمی‌کنم]
# 1                     دو یا سه       [PHP, Javascript]
# 2                     دو یا سه                    [C#]
# 3                     دو یا سه                  [Bash]
# 4                           یک  [PHP, Javascript, SQL]
#
#               want_to_work_languages                         database  \
# 0                             [Bash]                    [No Database]
# 1  [Python, Javascript, Go, Haskell]                  [MySQL/MariaDB]
# 2                       [Javascript]                 [MS-SQL, Oracle]
# 3                           [Python]                  [MySQL/MariaDB]
# 4                           [Python]  [MySQL/MariaDB, MongoDB, Redis]
#
#        desktop_os              server_os  \
# 0          [OS X]         [Linux CentOS]
# 1    [Linux Arch]         [Linux CentOS]
# 2    [Windows 10]  [Windows Server 2016]
# 3  [Linux Debian]         [Linux Debian]
# 4  [Linux Ubuntu]         [Linux Debian]
#
#                                  mobile_os  \
# 0  [Android, iOS, Dumb phones (1100, ...)]
# 1                                    [iOS]
# 2                                [Android]
# 3                                [Android]
# 4                                [Android]
#
#                                                  ide            ide_theme  \
# 0  [سابلایم, اتم, ادیتورهای متن ساده (نوت پد پلاس...                 تیره
# 1  [سابلایم, ادیتورهای متن ساده (نوت پد پلاس پلاس...                 تیره
# 2                                   [ویژوال استودیو]                 روشن
# 3                                           [mcedit]  گاهی روشن گاهی تیره
# 4                                  [محصولات جت برین]                 تیره
#
#     source_control                                         technology  \
# 0            [گیت]              [سورس کنترل, ویکی‌های مربوط به پروژه]
# 1            [گیت]                                       [سورس کنترل]
# 2  [گیت, اس وی ان]                                [سورس کنترل, کلاود]
# 3            [گیت]  [سورس کنترل, کانتینرها, بیلد سیستم ها, تست های...
# 4            [گیت]  [سورس کنترل, کانتینرها, بیلد سیستم ها, ویکی‌ها...
#
#                                    most_used_service tab_or_space  \
# 0  [ترلو, تودولیست‌ها, اسلک, ابزارهای مدیریت پروژ...           تب
# 1                  [استک اورفلو, ترلو, تسکولو, اسلک]        اسپیس
# 2  [استک اورفلو, ترلو, ابزارهای مدیریت پروژه مایک...           تب
# 3                   [استک اورفلو, تودولیست‌ها, اسلک]           تب
# 4                                [استک اورفلو, ترلو]           تب
#
#                                               drinks  \
# 0  [چای سیاه, قهوه, انواع ماء الشعیر, نوشیدنی‌های...
# 1  [چای سیاه, قهوه, انرژی زا, نوشابه, انواع ماء ا...
# 2  [چای سیاه, قهوه, دمنوش‌های متنوع, انرژی زا, نو...
# 3  [چای سیاه, دمنوش‌های متنوع, انرژی زا, نوشیدنی‌...
# 4                                               [آب]
#
#                                               style_ change_in_body  \
# 0  [تی شرت, جین, پیرهن مردونه, رسمی, گجت پوشیدنی ...      [هیچکدام]
# 1             [تی شرت, جین, پیرهن مردونه, شال, تیره]      [هیچکدام]
# 2                      [جین, شال, رنگی رنگی, اسپورت]      [هیچکدام]
# 3  [تی شرت, جین, گجت پوشیدنی دارم (ساعت هوشمند، ....      [هیچکدام]
# 4                                [جین, پیرهن مردونه]      [هیچکدام]
#
#                                            about_you  \
# 0  [بیشتر از یک نخ در روز سیگار می کشم, سیاست برا...
# 1  [بیشتر از یک نخ در روز سیگار می کشم, سیاست برا...
# 2  [بیشتر از یک نخ در روز سیگار می کشم, حداقل یک ...
# 3  [در رابطه نیستم ولی دوست داشتم بودم, حداقل یک ...
# 4  [به شکل مرتب نماز می‌خونم, بیشتر از سه بار در ...
#
#                                         music_style  \
# 0  [کلاسیک, سنتی, پاپ ایرانی, دامبول, بلوز, کانتری]
# 1                           [سنتی, پاپ ایرانی, راک]
# 2                  [کلاسیک, سنتی, پاپ ایرانی, بلوز]
# 3         [پاپ خارجی, متال, easy listening, دامبول]
# 4                                            [سنتی]
#
#                                         relationship how_many_devices  \
# 0                                     ازدواج کرده ام                4
# 1                                رابطه های نا پایدار                2
# 2                                     ازدواج کرده ام                1
# 3  با کامپیوتر/اینترنت/برنامه نویسی/سیستم عامل/.....          هیچکدام
# 4               بدون رابطه ولی علاقمند به شروع رابطه                1
#
#                      position  \
# 0   [مدیر شرکت / پروژه / ...]
# 1        [توسعه دهنده بک اند]
# 2        [توسعه دهنده بک اند]
# 3  [مدیر سیستم, مدیر دیتابیس]
# 4   [توسعه دهنده فول استک وب]
#
#                                         company_type  employees  \
# 0  [بخش آی تی شرکت های غیر نرم افزاری (مانند مخاب...      200.0
# 1                              [بخش دولتی, استارتاپ]       14.0
# 2                         [شرکت های تولید نرم افزار]      100.0
# 3                                         [استارتاپ]       20.0
# 4                                          [هیچکدام]        1.0
#
#       avg_monthly_salary                                   company_benefits  \
# 0      پنج تا هفت میلیون  [باشگاه ورزشی داخل شرکت, قهوه،‌ چای و ... رایگ...
# 1  دو تا سه و نیم میلیون            [ناهار رایگان, قهوه،‌ چای و ... رایگان]
# 2        یک تا دو میلیون  [قهوه،‌ چای و ... رایگان, کارت هدیه و کارت خری...
# 3  دو تا سه و نیم میلیون  [ناهار رایگان, قهوه،‌ چای و ... رایگان, برگزار...
# 4        یک تا دو میلیون                                          [هیچکدام]
#
#                                       work_type  \
# 0  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 1  نیمه وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 2  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 3  تمام وقت خصوصی (شامل استارتاپ‌های جا افتاده)
# 4                                پروژه ای مستقل
#
#                                    work_way            wage_per_hour  \
# 0         تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 1  اکثر مواقع دورکاری و گاهی به دفتر می روم  بین بیست و پنج تا پنجاه
# 2         تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 3         تمام وقت‌های کاری را در دفتر هستم        ساعتی کار نمی کنم
# 4             شخصی کار می کنم و در محل خودم  بین بیست و پنج تا پنجاه
#
#    satisfaction is_programming_your_main_job  \
# 0             4                          خیر
# 1             4                          بله
# 2             3                          بله
# 3             4                          بله
# 4             3                          بله
#
#                                                style
# 0  <pandas.io.formats.style.Styler object at 0x7f...
# 1  <pandas.io.formats.style.Styler object at 0x7f...
# 2  <pandas.io.formats.style.Styler object at 0x7f...
# 3  <pandas.io.formats.style.Styler object at 0x7f...
# 4  <pandas.io.formats.style.Styler object at 0x7f...

# %%
df_96.source_control[2]
# Out:
# ['گیت', 'اس وی ان']
