# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')
pd.set_option('display.max_columns', 500)

# %%
df_94 = pd.read_csv('data/1394.csv')
df_94.head()
# Out:
#             Timestamp در کدام محدوده سنی هستید؟ جنسیت  \
# 0  2/21/2016 16:41:37                  ۲۳ تا ۲۹   مرد
# 1  2/21/2016 16:45:37                  ۲۳ تا ۲۹   مرد
# 2  2/21/2016 16:47:21                  ۲۳ تا ۲۹   مرد
# 3  2/21/2016 16:49:20                  ۲۳ تا ۲۹   مرد
# 4  2/21/2016 16:52:44                  ۳۰ تا ۳۹    زن
#
#   خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (: استان محل کار  \
# 0                                              تهران             تهران
# 1                                              تهران             تهران
# 2                                              تهران             تهران
# 3                                     آذربایجان غربی             تهران
# 4                                            خوزستان             تهران
#
#   چند سال تجربه کار تمام وقت دارید؟          آخرین وضعیت تحصیلی  \
# 0                 هفت تا پانزده سال                      لیسانس
# 1                 هفت تا پانزده سال                      لیسانس
# 2                      یک تا سه سال  در حال تحصیل در فوق لیسانس
# 3                      یک تا سه سال                  فوق لیسانس
# 4                 هفت تا پانزده سال                      لیسانس
#
#   چه مدارک بین المللی ای اخذ کرده اید  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟  \
# 0                                     دو تا هفت ساعت
# 1                                     دو تا هفت ساعت
# 2                                    کمتر از دو ساعت
# 3                                 هفت تا چهارده ساعت
# 4                                    کمتر از دو ساعت
#
#   چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟  \
# 0                                    کمتر از دو ساعت
# 1                                     دو تا هفت ساعت
# 2                                    کمتر از دو ساعت
# 3                                    کمتر از دو ساعت
# 4                                    کمتر از دو ساعت
#
#   در سه ماه گذشته چند کتاب خوانده اید؟  \
# 0                             دو یا سه
# 1                             دو یا سه
# 2                             دو یا سه
# 3                             دو یا سه
# 4                             دو یا سه
#
#   زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟  \
# 0  سی شارپ, پایتون, ویژوال بیسیک, جاوااسکریپت, سو...
# 1      سی شارپ, جاوااسکریپت, اسکوئل, ای اس پی دات نت
# 2                        جاوا, پی اچ پی, جاوااسکریپت
# 3  سی پلاس پلاس, سی شارپ, پایتون, جاوااسکریپت, اس...
# 4                               سی شارپ, جاوااسکریپت
#
#   به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             دیتابیس‌های مورد استفاده  \
# 0                            MS-SQL, sqlite, MongoDB
# 1                                      MS-SQL, Redis
# 2                             MySQL/MariaDB, MongoDB
# 3  MS-SQL, sqlite, Hadoop Based technoloties, Mon...
# 4                                             MS-SQL
#
#   سیستم عامل رومیزی شما کدام است؟  \
# 0                   ویندوز ده, مک
# 1          ویندوز هفت, ویندوز هشت
# 2                              مک
# 3                       ویندوز ده
# 4                      ویندوز هشت
#
#                       سیستم عامل سرور مورد علاقه شما  \
# 0     ویندوز سرور ۲۰۱۶, لینوکس دبیان, لینوکس اوبونتو
# 1  ویندوز سرور ۲۰۰۳, ویندوز سرور ۲۰۰۸, ویندوز سرو...
# 2                                   لینوکس سنت او اس
# 3  ویندوز سرور ۲۰۱۲, ویندوز سرور ۲۰۱۶, لینوکس اوب...
# 4                                     ویندوزهای دیگر
#
#   و وقتی صحبت از تلفن همراه باشد...  \
# 0                          آی او اس
# 1                           اندروید
# 2                          آی او اس
# 3                           اندروید
# 4                          آی او اس
#
#                     در چه محیطی برنامه نویسی می‌کنید          تم آی دی ای  \
# 0                   ویژوال استودیو, سابلایم, ایکس کد                 روشن
# 1  ویژوال استودیو, ادیتورهای متن ساده (نوت پد پلا...  گاهی روشن گاهی تیره
# 2      سابلایم, محصولات جت برین, ویم, محصولات اکلیپس                 تیره
# 3     ویژوال استودیو, سابلایم, براکت, محصولات اکلیپس  گاهی روشن گاهی تیره
# 4                                     ویژوال استودیو                 تیره
#
#   از چه سورس کنترلی استفاده می کنید؟  تب یا اسپیس؟ نوشیدنی‌های اصلی شما چیست؟  \
# 0                                گیت            تب                       قهوه
# 1                                گیت            تب                         آب
# 2                                گیت  تفاوتی ندارد              چای, قهوه, آب
# 3                                NaN            تب                        چای
# 4                                گیت            تب       چای, دمنوش‌های متنوع
#
#   کدام‌ها در مورد شما صدق می‌کند  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#    به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   حوزه کاری شما چیست                نوع شرکت شما کدام است؟  \
# 0            توسعه دهنده فول استک وب              شرکت های تولید نرم افزار
# 1                 توسعه دهنده بک اند              شرکت های تولید نرم افزار
# 2                 توسعه دهنده بک اند              شرکت های تولید نرم افزار
# 3                       دانشمند داده  شرکت های ارائه دهنده سرویس های مختلف
# 4  توسعه دهنده بک اند, طراح, تحلیلگر              شرکت های تولید نرم افزار
#
#    تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)  \
# 0                                                 20
# 1                                                 25
# 2                                                 30
# 3                                                 25
# 4                                                 25
#
#   متوسط درآمد ماهیانه شما (به تومان)  \
# 0                  پنج تا هفت میلیون
# 1             سه و نیم تا پنج میلیون
# 2              دو تا سه و نیم میلیون
# 3              دو تا سه و نیم میلیون
# 4                  پنج تا هفت میلیون
#
#   محل کار چه خدماتی بیشتر از حقوق ارائه می دهد چگونه کار می کنید؟  \
# 0                                          NaN     تمام وقت خصوصی
# 1                                          NaN     تمام وقت خصوصی
# 2                                          NaN     تمام وقت خصوصی
# 3                                          NaN     تمام وقت خصوصی
# 4                                          NaN     تمام وقت خصوصی
#
#                       شیوه کار شما کدام است؟  \
# 0          تمام وقت‌های کاری را در دفتر هستم
# 1  اکثر وقت‌ها در دفتر ولی دورکاری هم می کنم
# 2          تمام وقت‌های کاری را در دفتر هستم
# 3          تمام وقت‌های کاری را در دفتر هستم
# 4          تمام وقت‌های کاری را در دفتر هستم
#
#   در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)  \
# 0                                  ساعتی کار نمی کنم
# 1                            بین بیست و پنج تا پنجاه
# 2                                  ساعتی کار نمی کنم
# 3                                  ساعتی کار نمی کنم
# 4                                                NaN
#
#    چقدر از کاری که انتخاب کرده اید راضی هستید؟  \
# 0                                            4
# 1                                            5
# 2                                            5
# 3                                            5
# 4                                            4
#
#   آیا نکته ای هست که بخواهید اضافه کنید؟ بنویسید...  تیپ   تغییر در بدن؟  \
# 0                                               NaN   NaN            NaN
# 1                                               NaN   NaN            NaN
# 2                                               NaN   NaN            NaN
# 3                                               NaN   NaN            NaN
# 4                                               NaN   NaN            NaN
#
#    سبک موسیقی  وضعیت رابطه  از کدام تکنولوزی ها استفاده می کنید  سبک لباس
# 0         NaN          NaN                                  NaN       NaN
# 1         NaN          NaN                                  NaN       NaN
# 2         NaN          NaN                                  NaN       NaN
# 3         NaN          NaN                                  NaN       NaN
# 4         NaN          NaN                                  NaN       NaN

# %%
df_94.columns
# Out:
# Index(['Timestamp', 'در کدام محدوده سنی هستید؟', 'جنسیت',
#        'خودتون رو متعلق به کدوم استان می دونین؟ بچه کجایین؟ (:',
#        'استان محل کار', 'چند سال تجربه کار تمام وقت دارید؟',
#        'آخرین وضعیت تحصیلی', 'چه مدارک بین المللی ای اخذ کرده اید',
#        'چند ساعت در هفته برای یادگیری تکنولوژی‌ها، زبان ها و ... جدید وقت می گذارید؟',
#        'چند ساعت در هفته برای پروژه‌های غیرکاری ولی مرتبط با حوزه کاری خود (برنامه نویسی، وبلاگنویسی، گزارش باگ، ...) وقت می گذارید؟',
#        'در سه ماه گذشته چند کتاب خوانده اید؟',
#        'زبان‌های برنامه‌نویسی مورد استفاده شما در پروژه‌ها کدامند؟',
#        'به جز زبان‌های فعلی‌تان، دوست دارید با چه زبان برنامه ای نویسی کار کنید؟',
#        'دیتابیس‌های مورد استفاده', 'سیستم عامل رومیزی شما کدام است؟',
#        'سیستم عامل سرور مورد علاقه شما', 'و وقتی صحبت از تلفن همراه باشد...',
#        'در چه محیطی برنامه نویسی می‌کنید', 'تم آی دی ای',
#        'از چه سورس کنترلی استفاده می کنید؟', 'تب یا اسپیس؟',
#        'نوشیدنی‌های اصلی شما چیست؟', 'کدام‌ها در مورد شما صدق می‌کند',
#        'به طور معمول چند دیوایس دیجیتال با خودتان حمل می کنید (شامل لپ تاپ، پخش کننده موزیک، موبایل،‌ کتابخوان، ...)',
#        'حوزه کاری شما چیست', 'نوع شرکت شما کدام است؟',
#        'تعداد مجموع کارمندان شرکت (در صورتی که انفرادی کار می کنید: 1)',
#        'متوسط درآمد ماهیانه شما (به تومان)',
#        'محل کار چه خدماتی بیشتر از حقوق ارائه می دهد', 'چگونه کار می کنید؟',
#        'شیوه کار شما کدام است؟',
#        'در صورتی که ساعتی کار می کنید، حقوق ساعتی شما چقدر است؟ (تومان)',
#        'چقدر از کاری که انتخاب کرده اید راضی هستید؟',
#        'آیا نکته ای هست که بخواهید اضافه کنید؟ بنویسید...', 'تیپ ',
#        'تغییر در بدن؟', 'سبک موسیقی', 'وضعیت رابطه',
#        'از کدام تکنولوزی ها استفاده می کنید', 'سبک لباس'],
#       dtype='object')

# %%
df_94.columns = ('time', 'age', 'gender', 'home_province', 'work_province', 'experience_years', 'education', 'international_certificates', 'learning_per_week', 'fun_projects_per_week', 'books_read_last_three_months', 'programming_languages', 'want_to_work_languages', 'database', 'desktop_os', 'server_os', 'mobile_os', 'ide', 'ide_theme', 'source_control', 'tab_or_space', 'drinks', 'about_you', 'how_many_devices', 'position', 'company_type', 'employees', 'avg_monthly_salary', 'company_benefits', 'work_type', 'work_way', 'wage_per_hour', 'satisfaction', 'comment', 'style', 'change_in_body', 'music_style', 'relationship', 'technology', 'clothing_style')

# %%
df_94.head()
# Out:
#                  time       age gender   home_province work_province  \
# 0  2/21/2016 16:41:37  ۲۳ تا ۲۹    مرد           تهران         تهران
# 1  2/21/2016 16:45:37  ۲۳ تا ۲۹    مرد           تهران         تهران
# 2  2/21/2016 16:47:21  ۲۳ تا ۲۹    مرد           تهران         تهران
# 3  2/21/2016 16:49:20  ۲۳ تا ۲۹    مرد  آذربایجان غربی         تهران
# 4  2/21/2016 16:52:44  ۳۰ تا ۳۹     زن         خوزستان         تهران
#
#     experience_years                   education international_certificates  \
# 0  هفت تا پانزده سال                      لیسانس                        NaN
# 1  هفت تا پانزده سال                      لیسانس                        NaN
# 2       یک تا سه سال  در حال تحصیل در فوق لیسانس                        NaN
# 3       یک تا سه سال                  فوق لیسانس                        NaN
# 4  هفت تا پانزده سال                      لیسانس                        NaN
#
#     learning_per_week fun_projects_per_week books_read_last_three_months  \
# 0      دو تا هفت ساعت       کمتر از دو ساعت                     دو یا سه
# 1      دو تا هفت ساعت        دو تا هفت ساعت                     دو یا سه
# 2     کمتر از دو ساعت       کمتر از دو ساعت                     دو یا سه
# 3  هفت تا چهارده ساعت       کمتر از دو ساعت                     دو یا سه
# 4     کمتر از دو ساعت       کمتر از دو ساعت                     دو یا سه
#
#                                programming_languages want_to_work_languages  \
# 0  سی شارپ, پایتون, ویژوال بیسیک, جاوااسکریپت, سو...                    NaN
# 1      سی شارپ, جاوااسکریپت, اسکوئل, ای اس پی دات نت                    NaN
# 2                        جاوا, پی اچ پی, جاوااسکریپت                    NaN
# 3  سی پلاس پلاس, سی شارپ, پایتون, جاوااسکریپت, اس...                    NaN
# 4                               سی شارپ, جاوااسکریپت                    NaN
#
#                                             database              desktop_os  \
# 0                            MS-SQL, sqlite, MongoDB           ویندوز ده, مک
# 1                                      MS-SQL, Redis  ویندوز هفت, ویندوز هشت
# 2                             MySQL/MariaDB, MongoDB                      مک
# 3  MS-SQL, sqlite, Hadoop Based technoloties, Mon...               ویندوز ده
# 4                                             MS-SQL              ویندوز هشت
#
#                                            server_os mobile_os  \
# 0     ویندوز سرور ۲۰۱۶, لینوکس دبیان, لینوکس اوبونتو  آی او اس
# 1  ویندوز سرور ۲۰۰۳, ویندوز سرور ۲۰۰۸, ویندوز سرو...   اندروید
# 2                                   لینوکس سنت او اس  آی او اس
# 3  ویندوز سرور ۲۰۱۲, ویندوز سرور ۲۰۱۶, لینوکس اوب...   اندروید
# 4                                     ویندوزهای دیگر  آی او اس
#
#                                                  ide            ide_theme  \
# 0                   ویژوال استودیو, سابلایم, ایکس کد                 روشن
# 1  ویژوال استودیو, ادیتورهای متن ساده (نوت پد پلا...  گاهی روشن گاهی تیره
# 2      سابلایم, محصولات جت برین, ویم, محصولات اکلیپس                 تیره
# 3     ویژوال استودیو, سابلایم, براکت, محصولات اکلیپس  گاهی روشن گاهی تیره
# 4                                     ویژوال استودیو                 تیره
#
#   source_control  tab_or_space                drinks about_you  \
# 0            گیت            تب                  قهوه       NaN
# 1            گیت            تب                    آب       NaN
# 2            گیت  تفاوتی ندارد         چای, قهوه, آب       NaN
# 3            NaN            تب                   چای       NaN
# 4            گیت            تب  چای, دمنوش‌های متنوع       NaN
#
#    how_many_devices                           industry  \
# 0               NaN            توسعه دهنده فول استک وب
# 1               NaN                 توسعه دهنده بک اند
# 2               NaN                 توسعه دهنده بک اند
# 3               NaN                       دانشمند داده
# 4               NaN  توسعه دهنده بک اند, طراح, تحلیلگر
#
#                            company_type  employees      avg_monthly_salary  \
# 0              شرکت های تولید نرم افزار         20       پنج تا هفت میلیون
# 1              شرکت های تولید نرم افزار         25  سه و نیم تا پنج میلیون
# 2              شرکت های تولید نرم افزار         30   دو تا سه و نیم میلیون
# 3  شرکت های ارائه دهنده سرویس های مختلف         25   دو تا سه و نیم میلیون
# 4              شرکت های تولید نرم افزار         25       پنج تا هفت میلیون
#
#   company_benefits       work_type                                   work_way  \
# 0              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 1              NaN  تمام وقت خصوصی  اکثر وقت‌ها در دفتر ولی دورکاری هم می کنم
# 2              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 3              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
# 4              NaN  تمام وقت خصوصی          تمام وقت‌های کاری را در دفتر هستم
#
#              wage_per_hour  satisfaction comment  style  change_in_body  \
# 0        ساعتی کار نمی کنم             4     NaN    NaN             NaN
# 1  بین بیست و پنج تا پنجاه             5     NaN    NaN             NaN
# 2        ساعتی کار نمی کنم             5     NaN    NaN             NaN
# 3        ساعتی کار نمی کنم             5     NaN    NaN             NaN
# 4                      NaN             4     NaN    NaN             NaN
#
#    music_style  relationship  technology  clothing_style
# 0          NaN           NaN         NaN             NaN
# 1          NaN           NaN         NaN             NaN
# 2          NaN           NaN         NaN             NaN
# 3          NaN           NaN         NaN             NaN
# 4          NaN           NaN         NaN             NaN
